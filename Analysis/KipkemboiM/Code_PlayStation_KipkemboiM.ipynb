# %%
# !pip install PyMuPDF
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting PyMuPDF
#   Downloading pymupdf-1.25.5-cp39-abi3-win_amd64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.25.5-cp39-abi3-win_amd64.whl (16.6 MB)
#    ---------------------------------------- 0.0/16.6 MB ? eta -:--:--
#    ---------- ----------------------------- 4.2/16.6 MB 25.2 MB/s eta 0:00:01
#    ------------------------- -------------- 10.5/16.6 MB 27.3 MB/s eta 0:00:01
#    -------------------------------------- - 16.0/16.6 MB 27.2 MB/s eta 0:00:01
#    ---------------------------------------- 16.6/16.6 MB 24.9 MB/s eta 0:00:00
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.25.5
#   WARNING: The script pymupdf.exe is installed in 'C:\Users\mkemb\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import fitz  # PyMuPDF
import difflib

# Function to load and extract text from a PDF
def load_pdf_text(pdf_path):
    doc = fitz.open(pdf_path)
    all_text = ""
    for page_num in range(len(doc)):
        page = doc[page_num]
        all_text += page.get_text()
    return all_text

# Load both PDF files (raw string used to avoid escape sequence warnings)
text_us = load_pdf_text(r"data\PlayStation_Policy_US.pdf")
text_eu = load_pdf_text(r"data\PlayStation_Policy_EU.pdf")

# Compare the two documents
diff = difflib.unified_diff(
    text_us.splitlines(),
    text_eu.splitlines(),
    fromfile='US Policy',
    tofile='EU Policy',
    lineterm=''
)

# Print the differences
for line in diff:
    print(line)
# Out:
# --- US Policy
# +++ EU Policy
# @@ -1,20 +1,21 @@
#  About Us and this Policy
# +Who we are and how to get in touch
#  This Privacy Policy explains when we collect information about you, including Personal
#  Information (“PI”), what we collect, why we collect it, how we use it, who we share it with, where
#  it is processed, how we handle it and your choices and legal rights associated with this information.
# -Your use of our websites, products, services, or other online activities (“Services”) constitutes your
# -consent to these practices.
#  Scope of this Policy
# -Sony Interactive Entertainment LLC, Naughty Dog LLC, Sucker Punch Productions LLC,
# -Insomniac Games Inc., Bluepoint Games Inc., Valkyrie Entertainment LLC, Haven Interactive
# -Studios ULC, Repeat Technologies Inc., Firewalk Studios, LLC, PlayStation Publishing LLC, and
# -all Americas subsidiaries using the brand name PlayStation ("SIE", “we,” “our,” and “us”)
# -controls the information collected when you interact with PlayStation through our Services.
# -Contact Us
# -Please contact us with any privacy questions by phone at 1-800-345-7669 or online
# -at http://www.playstation.com/support. See the bottom of this Privacy Policy for additional ways
# -to contact us or to contact us for specific matters.
# +Sony Interactive Entertainment Europe Limited and its wholly owned subsidiaries Sony Interactive
# +Entertainment Network Europe Limited and Sony Interactive Entertainment Direct Europe
# +Limited (in countries in which PlayStation Direct is available) ("SIE", “we,” “our,” and “us”)
# +controls the information collected when you interact with PlayStation through our websites,
# +products, services, or other online activities (“Services”).
# +Sony Interactive Entertainment Europe Limited is established within the European Union (“EU”)
# +through its subsidiaries located in France, Germany, Poland, the Netherlands, Spain, Portugal,
# +Italy, and Finland. Sony Interactive Entertainment Network Europe Limited and Sony Interactive
# +Entertainment Direct Europe Limited have appointed Sony Interactive Entertainment Europe
# +Limited as its EU data protection representative.
#  Information That We Collect or Receive
# +What data we collect about you
#  We collect and receive information from and about you by different means as described below.
#  Information You Provide to Us
#  We collect the information that you directly provide to us, such as when you enter it on our website,
# @@ -22,25 +23,26 @@
#  business support processes, such as:
#  •
#  Registration or PlayStation Network Account (“Account”) Creation Processes, where we
# -ask you to provide information such as: Contact info (e.g. name, email or physical address,
# -country, or phone number); Account Administration Info (e.g. user name, password, or
# -security questions); Billing Information (e.g. credit card or other payment number, billing
# -address); Date of Birth; and Profile Info (e.g. profile photo, languages, likes).
# +ask you to provide information such as: Contact information (e.g. name, email or physical
# +address, country, or phone number); Account Administration information (e.g. user name,
# +password, or security questions); Billing information (e.g. credit card or other payment
# +number, billing address); Date of Birth; and Profile information (e.g. profile photo,
# +languages, likes) .
#  •
#  Purchase Processes, where we may ask you to provide additional billing info to process
#  payment.
#  •
# -Technical and Customer Support Processes, where we may ask you to provide contact info
# -and information related to the issue you are contacting us about. We may also record calls
# -you make to PlayStation Support.
# +Technical and Customer Support Processes, where we may ask you to provide contact
# +information and information related to the issue you are contacting us about. We may also
# +record calls you make to PlayStation Support.
#  •
#  Other business processes, where we may ask you to provide information such as name,
#  email address, and Account ID if you participate in market research surveys, beta and other
#  user testing research, competitions, promotions or events or agree to receive marketing
#  information from us.
#  In addition, we collect the information that you provide by entering it into certain Service features.
# -For example, when you want to post in a forum, you provide us the content for the post (which
# -could contain PI which we collect and then display for you on the forum). Likewise, when you use
# +For example, when you want to post in a blog, you provide us the content for the blog post (which
# +could contain PI which we collect and then display for you on the blog). Likewise, when you use
#  other features such as voice or text messaging, blogs, surveys, user-generated content, activity
#  streams, or social media, we may first collect the information you enter into the feature.
#  Please make sure that any personal details which you provide are accurate and current. We will
# @@ -58,39 +60,39 @@
#  The information that we collect from devices may include:
#  •
#  Device identifiers such as your PlayStation console ID, mobile device IDs, cookie IDs, or
# -serial numbers
# -•
# -Network identifiers such as your IP address and MAC address
# -•
# -Account authentication tokens that avoid you having to log in repeatedly
# -•
# -Content and ads downloaded to your device for the online services that you access
# -•
# -Your current and recent locations (e.g. on PS Vita)
# -•
# -Trophies, scores and rankings achieved online and offline
# +serial numbers.
# +•
# +Network identifiers such as your IP address and MAC address.
# +•
# +Account authentication tokens that avoid you having to log in repeatedly.
# +•
# +Content and ads downloaded to your device for the online services that you access.
# +•
# +Your current and recent locations.
# +•
# +Trophies, scores and rankings achieved online and offline.
#  •
#  Information about the device you are using, any connected peripherals (such as controllers
# -and VR headsets) and how you have configured them
# +and VR headsets) and how you have configured them.
#  •
#  Information about how you use the software installed on your device (which may include
#  information about the use of the software offline), such as date and time of use, what games
#  or music you play, what content you browse, share or download, what services you access
# -and for how long, including how often you use chat and other communication applications
# +and for how long, including how often you use chat and other communication applications.
#  •
#  The actions you take within games or apps published by SIE (e.g. what obstacle you jump
# -over and what levels you reach)
# +over and what levels you reach).
#  •
#  Software errors and load times details, and if you have the "Report System Software Errors
#  Automatically" setting turned on, detailed information about the crash, including
# -screenshots and video captured before the crash
# +screenshots and video captured before the crash.
#  On a device or app basis, depending on your region, and for games released after March 2018, you
#  may be provided with choices that control our collection of information. For further information
#  on these options, refer to the Choices section of this Privacy Policy below.
#  PlayStation Network and Store
#  Each time you sign into PlayStation Network and access our Services, we may automatically:
#  •
# -Collect information about your use of PlayStation Network Services on your device.
# +Collect information about your use of PlayStation Network Services on your device.
#  •
#  Log your activity on our PlayStation Network servers. For example, we may receive device
#  and Account identifiers, such as your PlayStation Network Online ID and Account ID. We
# @@ -103,7 +105,7 @@
#  Entertainment company we may automatically:
#  •
#  Collect information about your use of that game on your device (including for offline
# -games, which may include information about the use of the game offline).
# +games, which may include information about the use of the game offline).
#  •
#  Log your activity on our game servers. For example, we may receive device and Account
#  identifiers, such as PlayStation Network Online ID, information about how you use our
# @@ -114,7 +116,8 @@
#  on web, emails, or advertising and marketing servers we control through cookies (small
#  information files placed on a hard drive), web beacons, tracking pixels, browser configuration
#  details (e.g. browser type, list of installed plugins and list of installed fonts), and embedded scripts
# -(programming code that is temporarily downloaded onto a device).
# +(programming code that is temporarily downloaded onto a device) and, website personalisation
# +settings.
#  Information We Receive from Third Parties
#  We may receive information, including the following, from third party sources and combine it with
#  information we already directly collect from you. We will handle the information in accordance
# @@ -125,31 +128,61 @@
#  •
#  Information from other users, for example if those users have given us access to their
#  profiles and if you are one of their connections, or information about you is otherwise made
# -accessible to us by them.
# -•
# -Information from third-parties as appropriate given our relationship, for example from anti-
# +accessible to us by them.
# +•
# +Information from third parties as appropriate given our relationship, for example from anti-
#  fraud service providers we might obtain fraud risk scores; from law enforcement or
#  partners, we might obtain IP addresses and details of suspected unlawful or malicious
# -activity.
# +activity.
#  •
#  Card account update information provided by your bank to help keep your payment cards
#  up to date on your Account. Following any update, we will continue to charge the
#  applicable payment methods to any purchases you make unless you notify us otherwise.
#  Information Use
# -This section explains how we may use the information we collect about you. We may combine
# -information from any of the sources explained in the “Information That We Collect or Receive”
# -section of this Privacy Policy. For example, we may process together information we have
# -collected from you, your visits to our website, your device gameplay history, etc., for the purposes
# -explained in this Privacy Policy.
# +How we use the data we collect
# +This section explains how we may use the PI we collect about you.
# +We will only use your PI for certain specified reasons and only where we have a lawful basis to
# +do so. The lawful bases we rely on depend on the type of relationship we have with you and how
# +we interact with you. Further details about the purposes on which we process your PI under these
# +lawful bases are set out in the sections for Information that We Collect of Receive, Information
# +Use, Information Sharing and Transfers. These purposes include the following:
# +•
# +Contract – to provide our products and services to you and fulfil our contractual
# +relationship with you. For example, when you make a purchase on PlayStation Store, we
# +process your PI to take payment and (if applicable) deliver items to you.
# +•
# +Legitimate Interests – to fulfil our legitimate interests, or those of a third party in
# +conducting and managing our business and our relationship with you as described in this
# +Privacy Policy. For example, we rely on legitimate interest to (a) detect and prevent fraud,
# +the unauthorised use of our Services, and other harmful or illegal activity, including by
# +reviewing reports submitted by other PlayStation users, (b) improve our products and
# +services, including by performing analytics and business reporting in relation to how you
# +use our Services and any issues you may encounter, and (c) share information with other
# +Sony Group Corporation companies where necessary to support the security of our
# +Services.
# +•
# +Legal obligation – to meet our legal obligations under applicable law, including to comply
# +with financial reporting requirements.
# +•
# +Consent – where you have provided us consent to process your PI for a specific purpose.
# +including to send marketing messages and personalised advertisements to you. When we
# +process your PI on the basis of consent, you can withdraw your consent at any time. See
# +the Choices section of this Privacy Policy for more information.
# +•
# +We may combine information from any of the sources explained in the “Information That
# +We Collect or Receive” section of this Privacy Policy. For example, we may process
# +together information we have collected from you, your visits to our website, your device
# +gameplay history, etc., for the purposes explained in this Privacy Policy.
#  Services
# -We may use your information to operate our Services. We may also personalize the services we
# -provide to you based on the information we have collected about you (for instance, we may use
# -your IP address to display content relevant for your area). And, to enable accessibility settings
# -functions (for you, or other users), we may convert your voice data to text.
# +We may use your information to operate our Services.
# +We may also personalise the services we provide to you based on the information we have collected
# +about you (for instance, we may use your IP address to display content relevant for your area) and,
# +to enable accessibility settings functions (for you, or other users), we may convert your voice data
# +to text.
#  Development
#  We use the information we collect to understand, improve and enhance our existing Services, your
#  experiences with them, and our business operations, and to develop new ones. For example, we
# -may use the information to develop and optimize user interfaces or game performance.
# +may use the information to develop and optimise user interfaces or game performance.
#  Moderation and Safety
#  We cannot monitor the whole of PlayStation Network and make no commitment to do so.
#  However, we reserve the right in our sole discretion to monitor (including through the use of
# @@ -160,13 +193,13 @@
#  Software License Agreements, any other terms of service you have agreed to and any rules or
#  codes of conduct applicable to your use of PlayStation Network.
#  Marketing and Advertising
# -We may target and personalize our marketing communications, purchase recommendations and
# +We may target and personalise our marketing communications, purchase recommendations and
#  advertisements that we display on our and third-party websites and services based on the
# -information we have collected about you. You may notice this personalization on the PlayStation
# +information we have collected about you. You may notice this personalisation on the PlayStation
#  Store (whether via console, website or in-game), in marketing communications, or when you visit
#  our and third-party websites (such as social network sites) that show purchase recommendations
#  or advertisements from us.  You have options to control our use of information we have collected
# -about you to personalize marketing to you, and can learn more about them in the Choices section
# +about you to personalise marketing to you and can learn more about them in the Choices section
#  of this Privacy Policy.
#  Legal and Compliance
#  We may use the information we collect for auditing, compliance and legal purposes (for example,
# @@ -175,14 +208,15 @@
#  In order to help protect you and others, we may use the information we collect and receive in order
#  to:
#  •
# -Identify fraudulent activities and transactions.
# +Identify fraudulent activities and transactions.
#  •
#  Prevent abuse of and investigate and/or prosecute any potential threat to or misuse of our
# -Services.
# -•
# -Protect your account from unauthorized access (for example by preventing access if an
# +Services.
# +•
# +Protect your account from unauthorised access (for example by preventing access if an
#  attempt is made to log-in from a new location).
#  Information Sharing and Transfers
# +Who we share data with and where
#  This section explains how we may share the information we collect with third parties that provide
#  services to us or provide games and apps on PlayStation Network that you use. We do not and will
#  not accept money in exchange for sharing PI. We may share your information with the following
# @@ -190,33 +224,26 @@
#  Service Providers
#  We share information with service providers to SIE, who are persons or companies that provide
#  services which may include handling PI for any of the purposes described in this Privacy Policy.
# -Service providers are required to adhere to this Privacy Policy, and confidentiality and security
# -requirements.
# +Service providers are required to adhere to confidentiality and security requirements.
#  Partners
#  We may share information with the following partners:
#  •
# -Financial organizations, such as payment details in order to complete your purchase, obtain
# -payment and carry out credit and anti-fraud checks.
# -•
# -Game publishers, such as the content you have purchased from PlayStation Store so that
# -they can deliver that content to you in-game, and ensure your entitlement to access that
# -content is reflected across different gaming platforms.
# +Financial organisations, such as payment details in order to complete your purchase, obtain
# +payment and carry out credit and anti-fraud checks.
# +•
# +Game publishers of the content you have purchased from PlayStation Store so that they
# +can deliver that content to you in-game, and ensure your entitlement to access that content
# +is reflected across different gaming platforms.
#  •
#  Other service, application or website providers, for operational purposes, or for additional
#  purposes, with your permission (such as when you link your Account to your account with
# -them).
# -•
# -Security and fraud partners, as appropriate to support the security of our Services, fraud
# -prevention, or protect PI.
# +them).
# +•
# +Security and fraud partners, including Sony Group, as appropriate to support the security
# +of our Services, fraud prevention, or protect PI.
#  •
#  Advertising and promotional partners, with whom we are jointly delivering services or
# -features, such as sweepstakes, contests, promotions, or advertising.
# -•
# -Sony Group, for purposes related to providing you with content, products, or services,
# -including games, videos, music, software and software applications; community
# -administration or development; to support various business and security processes;
# -research and development; and so that other Sony group companies may contact you about
# -products, services or other offerings that may be of interest to you.
# +features, such as sweepstakes, contests, promotions, or advertising.
#  •
#  Business transfer partners, in connection with the negotiation and sale of the applicable
#  business, a portion of the business, or certain stock and/or assets, or a corporate merger,
# @@ -227,72 +254,73 @@
#  make it accessible to all accounts on PlayStation Network, on the Internet via playstation.com, and
#  some third-party websites, apps or services. This information includes:
#  •
# -Your PlayStation Network Online ID
# -•
# -"About Me" statement, avatar, language, country and gaming scores and statistics
# -•
# -Content you have shared
# -You are responsible for any content you share on forums, communities, chat and messaging
# -features. This content will be accessible to other users who can then share that information further.
# -We recommend you consider carefully what you share and with whom you share your information.
# +Your PlayStation Network Online ID.
# +•
# +"About Me" statement, avatar, language, country and gaming scores and statistics.
# +•
# +Content you have shared.
# +You are responsible for any content you share using blogs, chat, and messaging features. This
# +content will be accessible to other users who can then share that information further. We
# +recommend you consider carefully what you share and with whom you share your information.
#  We may also index and use content which you have shared publicly, as part of our platform’s
#  features like Game Help, PlayStation profiles, or future PlayStation Network services.
# -Government Authorities
# -We may share your information with police and other government authorities if we believe that it
# -is reasonably necessary to comply with a law, regulation, or legal process, to detect, protect and
# +Government & Authorities
# +We may share your information with police, government, and other authorities if we believe that
# +it is reasonably necessary to comply with a law, regulation, or legal process, to detect, protect and
#  enforce the safety of any person, their property or their rights, to address fraud and security and
# -report criminal activity. The majority of the cases in which we have shared information with police
# -and government authorities concern their investigations into stolen devices, unauthorized use of
# -payment methods, or moderation purposes and safety of PlayStation Network and its users. In a
# -small number of cases, we have also provided information in response to anti-fraud or more serious
# -criminal investigations.
# +report criminal activity. The majority of the cases in which we have shared information with police,
# +government, and other authorities concern their investigations into stolen devices, unauthorised
# +use of payment methods, or moderation purposes and safety of PlayStation Network and its users.
# +In a small number of cases, we have also provided information in response to anti-fraud or more
# +serious criminal investigations.
#  Information Handling and Your Choices
# +How we store your data and your rights
#  Children’s Information
# -We are committed to respecting children's privacy. We will not collect PI from anyone we have
# -actual knowledge is under the age of 13, without a parent's consent. We do not share the PI of
# -children who we have actual knowledge are under the age of 16 for delivery of advertising
# -purposes. If you are creating an account for your child, we recommend that you and your child
# -read our Privacy Information for Young Players to help them understand how we handle their PI
# -and their rights over their PI.
# -With parental consent, we will collect, use and share information collected from or about children
# -in accordance with the practices described in this document, with the following exceptions.
# +Accounts for children between the age of 7 to 17 years old, must be created by your parent or legal
# +guardian ("Responsible Adult"). If you are creating an account for your child, we recommend that
# +you and your child read our Privacy Information for Young Players to help them understand how
# +we handle their PI and their rights over their PI.
# +If you are aged 7 - 17, you can ask your Responsible Adult to explain anything you do not
# +understand. You can also read our Privacy Information for Young Players to help you understand
# +how we use your information and your privacy rights over your information.
# +We will collect, use and share information collected from or about children in accordance with the
# +practices described in this document, with the following exceptions.
#  Information You Provide to Us
#  •
# -A parent only needs to provide limited information about their child (an email address and
# -date-of-birth) to create an Account for their child. Providing gender is optional.
# -•
# -Only with the parent's approval to create an Account for the child, can a child add their
# -address.
# -•
# -The spending limit of the Account for your child is set by the associated parent's Account.
# +A Responsible Adult only needs to provide limited information about their child (an email
# +address and date-of-birth) to create an Account for their child. Providing gender is
# +optional.
# +•
# +Only with the Responsible Adult’s approval to create an Account for the child, can a child
# +add their address.
# +•
# +The spending limit of the Account for your child is set by the associated Responsible
# +Adult’s Account.
#  Information You May Choose to Share
#  •
# -A parent can control, through the “Free Communication” setting on their child's Account,
# -their child's ability to use (and share PI through) text chat, voice chat, video chat, and other
# -messaging features from communicating directly with other users in games, apps or via
# -system software features. Please note that a child's Account can still (1) Send and receive
# -predetermined text messages created by a game or app, (2) Create and see other users' in-
# -game character names, designs, and clan titles, (3) Use communication services via an
# -Internet browser unless specifically disabled, and (4) Communicate via system messaging
# -on PS3 and PS Vita.
# -•
# -A parent can control their child's ability to post or view user-generated content, including
# -photos, videos, drawings, and content imported from outside sources (any of which might
# -contain PI) through the user-generated content control. This will not prevent video capture
# -of a child Account user's online gameplay.
# -•
# -A parent can agree to our collection and use of their child's PI without consenting to our
# -disclosure to third parties, except when the disclosure is inherent to the Services we are
# -providing.
# -When a parent allows their child's Account to participate in games, chat or user-generated content
# -features, they also consent to SIE sharing information with the publishers of the games,
# -applications, or services that incorporate those features and the collection of information entered
# -into such features by the child's Account (e.g. typing text into the chat feature).
# -If you discover your child under the age of 13 has provided PI to us without your consent, once
# -we verify you are the child's parent, we will promptly: (a) provide direct notice to you indicating
# -what, if any PI of your child has been collected and how it has been used or disclosed; (b) remove
# -and cease the use of your child's PI or other information from our database and (c) by notice to
# -you, confirm compliance with the foregoing.
# +A Responsible Adult can control, through the “Free Communication” setting on their
# +child's Account, their child's ability to use (and share PI through) text chat, voice chat,
# +video chat, and other messaging features from communicating directly with other users in
# +games, apps or via system software features. Please note that a child's Account can still (1)
# +send and receive predetermined text messages created by a game or app, (2) create and see
# +other users' in-game character names, designs, and clan titles, and (3) use communication
# +services via an Internet browser unless specifically disabled.
# +•
# +A Responsible Adult can control their child's ability to post or view user-generated content,
# +including photos, videos, drawings, and content imported from outside sources (any of
# +which might contain PI) through the user-generated content control. This will not prevent
# +video capture of a child Account user's online gameplay.
# +•
# +A Responsible Adult can agree to our collection and use of their child's PI without
# +consenting to our disclosure to third parties, except when the disclosure is inherent to the
# +Services we are providing.
# +When a Responsible Adult allows their child's Account to participate in games, chat or user-
# +generated content features, they also allow consent to SIE sharing information with the publishers
# +of the games, applications, or services that incorporate those features and the collection of
# +information entered into such features by the child's Account (e.g. typing text into the chat feature).
# +If you discover your child under the age of 18 has created an Account, once we verify you are the
# +child's Responsible Adult parent, we will promptly give access and control of the child’s account
# +to you.
#  International Transfers
#  Our Services are operated in the United States, United Kingdom, Japan, and other
#  countries/areas/regions around the world. Please be aware that information we collect, including
# @@ -306,8 +334,8 @@
#  the privacy laws may not be as comprehensive as those in the country where you reside or are a
#  citizen.
#  Security and Retention
# -We seek to maintain appropriate technical and organizational security measures that conform to
# -industry standards to help protect your information against unauthorized or accidental disclosure,
# +We seek to maintain appropriate technical and organisational security measures that conform to
# +industry standards to help protect your information against unauthorised or accidental disclosure,
#  access, misuse, loss, or alteration. Although we strive to protect your information, we cannot
#  ensure or warrant the security of such information. There is no such thing as perfect security.
#  We advise you to make use of the enhanced account access controls that we make available such
# @@ -317,125 +345,136 @@
#  them to anyone else. Consider ensuring automatic account log-in setting is disabled and the setting
#  requiring a password to be entered before completing purchases is enabled, particularly if your
#  PlayStation device is shared with others. You should contact PlayStation Support immediately if
# -you become aware of any unauthorized use of your accounts or other security breaches.
# -We may retain information about you as long as it is necessary for us to fulfill the purposes outlined
# -in this policy. In addition, we may retain your information for an additional period as is permitted
# -or required to, among other things, comply with our legal obligations, resolve disputes, and enforce
# -agreements. Where required by applicable law, we shall delete your information when the
# -information is no longer necessary or requested to do so. Even if we delete your information from
# -active databases, the information may remain on backup or archival media as well as other
# +you become aware of any unauthorised use of your accounts or other security breaches.
# +We may retain information about you as long as it is necessary for us to fulfil the purposes outlined
# +in this Privacy Policy. In addition, we may retain your information for an additional period as is
# +permitted or required to, among other things, comply with our legal obligations, resolve disputes,
# +and enforce agreements. Where required by applicable law, we shall delete your information when
# +the information is no longer necessary or requested to do so. Even if we delete your information
# +from active databases, the information may remain on backup or archival media as well as other
#  information systems.
#  Your Choices and Rights
#  Your Choices
#  You may have certain choices about how your information is collected, used, stored, and
#  shared.  These options can be accessed through your Account or device settings.  Please ensure
# -that your information is up-to-date. Among others, you have the following choices:
# -•
# -Personalized content and marketing: Whether we may use the information we have
# -collected about you to personalize advertising and purchase recommendations. Note that
# -we will always slightly customize what you see (e.g. to avoid displaying content you've
# -already purchased from the PlayStation Store), and some older devices (e.g. PS3/Vita),
# -apps and games may still show some commercial personalization.
# -•
# -Personalized communications: Whether we may use the information we have collected, to
# -personalize emails and notifications.
# -•
# -Limited Data/Service Data and Full Data/Advanced Data collection: Whether we may
# +that your information is up to date. Among others, you have the following choices:
# +•
# +Personalised content and marketing: Whether we may use the information we have
# +collected about you to personalise advertising and purchase recommendations. Note that
# +we will always slightly customise what you see (e.g. to avoid displaying content you've
# +already purchased from the PlayStation Store), and some older devices, apps and games
# +may still show some commercial personalisation.
# +•
# +Personalised communications: Whether we may use the information we have collected, to
# +personalise emails and notifications.
# +•
# +Limited Data/Service Data and Full Data/Additional Data collection: Whether we may
#  collect only the Limited Data necessary to provide our Services, or Full Data to enable a
# -richer experience.
# -•
# -E-Mail Messages: Whether we send you marketing emails.
# +richer experience.
# +•
# +E-Mail Messages: Whether we send you marketing emails.
#  •
#  Sharing social PI: Whether to share other information, such as your real, name, PlayStation
# -Network friends, or activities.
# -•
# -Shared content: Whether to share content such as gameplay videos with other users.
# -Do Not Track (DNT)
# -"Do Not Track" is an internet browser setting regarding tracking. As there are currently no agreed
# -upon standards for the DNT signals or how to respond to them, we adhere to the standards set out
# -in this Privacy Policy.
# +Network friends, or activities.
# +•
# +Shared content: Whether to share content such as gameplay videos with other users.
# +•
# +Collection of cookies: You can manage cookies that are not strictly necessary for the
# +provision of our websites, this will also limit when we can recognise your visits to our
# +websites and target and personalise the advertising and commercial purchase
# +recommendations displayed on those websites.
#  Your Rights
# -In addition to the rights described below, you can also access, amend or delete some information
# -through your Account Settings page.
# -•
# -Request to Access and Correct: You have the right to request that we inform you of the PI
# -we hold about you, as well as to request the correction of any inaccurate information about
# -you.
# -•
# -Right of Access: You have the right to request that we inform you of the PI we have
# -collected, used and shared about you, and to obtain a copy of it.
# -•
# -Right of Deletion: You have the right to request that we delete the PI we have collected or
# -retained about you in some circumstances as defined by law. To request removal of certain
# -of your PI from a blog, forum, or message board, please contact us as described in the
# -Contact Us section above. Following your request for deletion, please be aware that the
# -information that we collect about you may still be retained for legal, accounting, business
# -continuity (backup), anti-fraud and community reasons.
# +You can access, amend or delete some information through your Account settings. You can also
# +exercise the rights described below by contacting us at www.playstation.com/data-subject-request.
# +We reserve the right to deny your requests if we cannot verify your identity.
# +•
# +Right of Access and Portability: You have the right to request certain information about the
# +processing of your PI and to be provided with a copy of your PI. To download a copy of
# +key PI that we process, sign-in to your Account on www.playstation.com and navigate to
# +[Account Settings] > [Privacy Settings] > [Data Access Requests].
# +•
# +Right of Erasure: You have the right to request that we delete the PI we have collected or
# +retained about you in some circumstances as defined by law.  To request removal of certain
# +of your PI from a blog or chat, please contact us as described in the Contact Us section
# +below. Following your request for deletion, please be aware that the information that we
# +collect about you may still be retained for legal, accounting, business continuity (backup),
# +anti-fraud and community reasons. You can close your account for PlayStation Network by
# +contacting PlayStation Support. Information collected from older games and apps may not
# +be integrated with account closure. Following your account closure request, please be
# +aware that the information that we collect about you may still be retained for legal,
# +accounting, business continuity (backup), anti-fraud and community reasons. If you have
# +accounts with other Sony group companies you will need to contact those companies
# +separately
# +to
# +close
# +those
# +accounts.
# +For
# +more
# +information,
# +visit
# +https://www.sony.co.uk/mysony.
# +•
# +Right of rectification: You have the right to rectify your information, restrict processing,
# +and object to the use of your PI in some circumstances as defined by law.
# +•
# +Right to Object: You have the right to object to the processing of your PI in certain
# +circumstances. For example, you have the right to object to the use of your PI for direct
# +marketing purposes.
# +•
# +Right to Restrict: You have the right to restrict the processing of your PI in certain
# +circumstances.
#  In some cases, your choices to provide, change or delete information may affect our ability to
#  deliver our Services, or your user experience. We may decline to process requests which are not
#  otherwise required by applicable law. You have the right not to be unlawfully discriminated against
#  because you have exercised these rights.
# -To
# -make
# -a
# -Request
# -to
# -Access
# -or
# -Deletion,
# -please
# -visit https://ps-
# -support.playstation.com/s/consumer-privacy?language=en_US&locale=en-us,
# -or
# -contact
# -Consumer Services toll-free at 1-800-345-7669. After you submit a request, we will require you
# -to confirm your request, and verify your identity by requesting details of your account, devices,
# -payment instruments or past transactions. We reserve the right to deny your requests if we cannot
# -verify your identity.
# -Right to Opt-Out of Share
# -We may share data about your activities related to PlayStation services, websites, and apps with
# -third parties to provide ads that are more personalized to you on third-party platforms. You may
# -opt-out of our sharing of your personal information by visiting the link below and completing the
# -web form: https://www.playstation.com/en-us/legal/third-party-ads/.
# -Alternatively, you may also opt-out by sending an email to sie-privacy@sony.com and providing
# -the email address associated with your PSN account.
# -This Privacy Policy is made available in an accessible format that is compatible with ADA
# -compliant web browsers.  For an alternative accessible PDF of the Privacy Policy please contact
# -1-800-345-7669.
# +For an alternative accessible PDF of the Privacy Policy please contact us using the information in
# +the Contact Us section of this Privacy Policy.
#  Complaints
# -ESRB Privacy Certified
# -This
# -Privacy
# -Statement
# -and
# -the
# -confirmation
# -page
# -at www.esrb.org/confirm/siea-
# -confirmation.aspx or accessed by clicking the seal in the footer of any page of playstation.com)
# -confirms that SIE is a valid licensee and participating member in the Entertainment Software
# -Rating Board's Privacy Certified Program. We have undertaken this privacy initiative and our
# -websites have been reviewed and certified by ESRB Privacy Online to meet established online
# -information collection and use practices. As part of the privacy program, we are subject to frequent
# -audits of our sites and other enforcement and accountability mechanisms administered
# -independently by ESRB.
# +If you have a concern about our handling of your PI, please get in contact with us first so we can
# +try to resolve your query using the details in the Contact Us section of this Privacy Policy. You can
# +also contact our Data Protection Officer via email at siee.dpo@sony.com.
# +If however you feel we have not dealt with your concern and/or that we are failing to meet our
# +legal obligations, you can report this to your local data protection regulator or the Information
# +Commissioner's Office ("ICO") in the United Kingdom. More information on reporting a concern
# +to the ICO can be found at https://ico.org.uk/.
# +Contact Us
# +Please contact us for further information about our Privacy Policy or our processing of your PI, by
# +either of the following methods:
# +Post:
# +Data
# +Protection
# +Office
# +Sony Interactive Entertainment Europe Limited / Sony Interactive Entertainment Network Europe
# +Limited
# +/
# +Sony
# +Interactive
# +Entertainment
# +Direct
# +Europe
# +Limited
# +10
# +Great
# +Marlborough
# +Street
# +London
# +United
# +Kingdom
# +W1F 7LP
# +Online:
# +You can contact us by using our web form:
# +www.playstation.com/data-subject-request
#
# -How to Contact Us About this Privacy Policy
# -For further information on our Privacy Policy, or how users can review or change their information,
# -please contact us at:
# -- By Phone at:
# -1-800-345-7669
# -- By Mail at:
# -SONY INTERACTIVE ENTERTAINMENT CONSUMER SERVICES DEPARTMENT
# -2207 BRIDGEPOINTE PARKWAY
# -SAN MATEO, CALIFORNIA, 94404
# -Online: www.playstation.com/support
# -SIE is a licensee of ESRB's Privacy Certified Program. If you believe that we have not responded
# -to your privacy-related inquiry or your inquiry has not been satisfactorily addressed, please contact
# -ESRB Privacy Certified at www.esrb.org/privacy/contact.aspx.
# +Sony Interactive Entertainment Europe Limited, Sony Interactive Entertainment Network Europe
# +Limited, and Sony Interactive Entertainment Direct Europe Limited are registered in England
# +under company numbers: 03277793, 06020283, and 03754597.
# +We have appointed Özdağıstanli Ekici Avukatlık Ortaklığı as our Turkish Data Controller
# +Representative. If you are located in Turkey, you can contact our Turkish Data Controller
# +Representative by email at info@iptech-legal.com.
#  Changes to this Policy
# -We may revise this Privacy Policy at any time and we will update this Policy with any revisions.
# -By continuing to access or use the Services after those changes become effective, you acknowledge
# -and accept that PI will be handled in accordance with the revised Privacy Policy.
# -Last Revised: 2023-06
# +We may revise this Privacy Policy at any time and we will update this Privacy Policy with any
# +revisions. By continuing to access or use the Services after those changes become effective, you
# +acknowledge and accept that PI will be handled in accordance with the revised Privacy Policy.
# +Version 9.2 (January 2024)

# %%
# Split into clauses/paragraphs (could also split by \n\n if needed)
clauses_us = [clause.strip() for clause in text_us.split('\n') if clause.strip()]
clauses_eu = [clause.strip() for clause in text_eu.split('\n') if clause.strip()]

# %%
# Compare clauses using SequenceMatcher
matcher = difflib.SequenceMatcher(None, clauses_us, clauses_eu)

# Display similar or different clauses
for opcode in matcher.get_opcodes():
    tag, i1, i2, j1, j2 = opcode

    if tag == 'equal':
        continue  # Skip identical clauses

    print(f"\n--- Difference: {tag.upper()} ---")
    print(f"US Policy Clause(s) [{i1}:{i2}]:")
    for clause in clauses_us[i1:i2]:
        print(f"  • {clause}")

    print(f"EU Policy Clause(s) [{j1}:{j2}]:")
    for clause in clauses_eu[j1:j2]:
        print(f"  • {clause}")
# Out:
# --- Difference: INSERT ---
# US Policy Clause(s) [1:1]:
# EU Policy Clause(s) [1:2]:
#   • Who we are and how to get in touch
#
# --- Difference: DELETE ---
# US Policy Clause(s) [4:6]:
#   • Your use of our websites, products, services, or other online activities (“Services”) constitutes your
#   • consent to these practices.
# EU Policy Clause(s) [5:5]:
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [7:16]:
#   • Sony Interactive Entertainment LLC, Naughty Dog LLC, Sucker Punch Productions LLC,
#   • Insomniac Games Inc., Bluepoint Games Inc., Valkyrie Entertainment LLC, Haven Interactive
#   • Studios ULC, Repeat Technologies Inc., Firewalk Studios, LLC, PlayStation Publishing LLC, and
#   • all Americas subsidiaries using the brand name PlayStation ("SIE", “we,” “our,” and “us”)
#   • controls the information collected when you interact with PlayStation through our Services.
#   • Contact Us
#   • Please contact us with any privacy questions by phone at 1-800-345-7669 or online
#   • at http://www.playstation.com/support. See the bottom of this Privacy Policy for additional ways
#   • to contact us or to contact us for specific matters.
# EU Policy Clause(s) [6:16]:
#   • Sony Interactive Entertainment Europe Limited and its wholly owned subsidiaries Sony Interactive
#   • Entertainment Network Europe Limited and Sony Interactive Entertainment Direct Europe
#   • Limited (in countries in which PlayStation Direct is available) ("SIE", “we,” “our,” and “us”)
#   • controls the information collected when you interact with PlayStation through our websites,
#   • products, services, or other online activities (“Services”).
#   • Sony Interactive Entertainment Europe Limited is established within the European Union (“EU”)
#   • through its subsidiaries located in France, Germany, Poland, the Netherlands, Spain, Portugal,
#   • Italy, and Finland. Sony Interactive Entertainment Network Europe Limited and Sony Interactive
#   • Entertainment Direct Europe Limited have appointed Sony Interactive Entertainment Europe
#   • Limited as its EU data protection representative.
#
# --- Difference: INSERT ---
# US Policy Clause(s) [17:17]:
# EU Policy Clause(s) [17:18]:
#   • What data we collect about you
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [24:28]:
#   • ask you to provide information such as: Contact info (e.g. name, email or physical address,
#   • country, or phone number); Account Administration Info (e.g. user name, password, or
#   • security questions); Billing Information (e.g. credit card or other payment number, billing
#   • address); Date of Birth; and Profile Info (e.g. profile photo, languages, likes).
# EU Policy Clause(s) [25:30]:
#   • ask you to provide information such as: Contact information (e.g. name, email or physical
#   • address, country, or phone number); Account Administration information (e.g. user name,
#   • password, or security questions); Billing information (e.g. credit card or other payment
#   • number, billing address); Date of Birth; and Profile information (e.g. profile photo,
#   • languages, likes) .
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [32:35]:
#   • Technical and Customer Support Processes, where we may ask you to provide contact info
#   • and information related to the issue you are contacting us about. We may also record calls
#   • you make to PlayStation Support.
# EU Policy Clause(s) [34:37]:
#   • Technical and Customer Support Processes, where we may ask you to provide contact
#   • information and information related to the issue you are contacting us about. We may also
#   • record calls you make to PlayStation Support.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [41:43]:
#   • For example, when you want to post in a forum, you provide us the content for the post (which
#   • could contain PI which we collect and then display for you on the forum). Likewise, when you use
# EU Policy Clause(s) [43:45]:
#   • For example, when you want to post in a blog, you provide us the content for the blog post (which
#   • could contain PI which we collect and then display for you on the blog). Likewise, when you use
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [60:71]:
#   • serial numbers
#   • •
#   • Network identifiers such as your IP address and MAC address
#   • •
#   • Account authentication tokens that avoid you having to log in repeatedly
#   • •
#   • Content and ads downloaded to your device for the online services that you access
#   • •
#   • Your current and recent locations (e.g. on PS Vita)
#   • •
#   • Trophies, scores and rankings achieved online and offline
# EU Policy Clause(s) [62:73]:
#   • serial numbers.
#   • •
#   • Network identifiers such as your IP address and MAC address.
#   • •
#   • Account authentication tokens that avoid you having to log in repeatedly.
#   • •
#   • Content and ads downloaded to your device for the online services that you access.
#   • •
#   • Your current and recent locations.
#   • •
#   • Trophies, scores and rankings achieved online and offline.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [73:74]:
#   • and VR headsets) and how you have configured them
# EU Policy Clause(s) [75:76]:
#   • and VR headsets) and how you have configured them.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [78:79]:
#   • and for how long, including how often you use chat and other communication applications
# EU Policy Clause(s) [80:81]:
#   • and for how long, including how often you use chat and other communication applications.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [81:82]:
#   • over and what levels you reach)
# EU Policy Clause(s) [83:84]:
#   • over and what levels you reach).
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [85:86]:
#   • screenshots and video captured before the crash
# EU Policy Clause(s) [87:88]:
#   • screenshots and video captured before the crash.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [116:117]:
#   • (programming code that is temporarily downloaded onto a device).
# EU Policy Clause(s) [118:120]:
#   • (programming code that is temporarily downloaded onto a device) and, website personalisation
#   • settings.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [129:130]:
#   • Information from third-parties as appropriate given our relationship, for example from anti-
# EU Policy Clause(s) [132:133]:
#   • Information from third parties as appropriate given our relationship, for example from anti-
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [138:143]:
#   • This section explains how we may use the information we collect about you. We may combine
#   • information from any of the sources explained in the “Information That We Collect or Receive”
#   • section of this Privacy Policy. For example, we may process together information we have
#   • collected from you, your visits to our website, your device gameplay history, etc., for the purposes
#   • explained in this Privacy Policy.
# EU Policy Clause(s) [141:175]:
#   • How we use the data we collect
#   • This section explains how we may use the PI we collect about you.
#   • We will only use your PI for certain specified reasons and only where we have a lawful basis to
#   • do so. The lawful bases we rely on depend on the type of relationship we have with you and how
#   • we interact with you. Further details about the purposes on which we process your PI under these
#   • lawful bases are set out in the sections for Information that We Collect of Receive, Information
#   • Use, Information Sharing and Transfers. These purposes include the following:
#   • •
#   • Contract – to provide our products and services to you and fulfil our contractual
#   • relationship with you. For example, when you make a purchase on PlayStation Store, we
#   • process your PI to take payment and (if applicable) deliver items to you.
#   • •
#   • Legitimate Interests – to fulfil our legitimate interests, or those of a third party in
#   • conducting and managing our business and our relationship with you as described in this
#   • Privacy Policy. For example, we rely on legitimate interest to (a) detect and prevent fraud,
#   • the unauthorised use of our Services, and other harmful or illegal activity, including by
#   • reviewing reports submitted by other PlayStation users, (b) improve our products and
#   • services, including by performing analytics and business reporting in relation to how you
#   • use our Services and any issues you may encounter, and (c) share information with other
#   • Sony Group Corporation companies where necessary to support the security of our
#   • Services.
#   • •
#   • Legal obligation – to meet our legal obligations under applicable law, including to comply
#   • with financial reporting requirements.
#   • •
#   • Consent – where you have provided us consent to process your PI for a specific purpose.
#   • including to send marketing messages and personalised advertisements to you. When we
#   • process your PI on the basis of consent, you can withdraw your consent at any time. See
#   • the Choices section of this Privacy Policy for more information.
#   • •
#   • We may combine information from any of the sources explained in the “Information That
#   • We Collect or Receive” section of this Privacy Policy. For example, we may process
#   • together information we have collected from you, your visits to our website, your device
#   • gameplay history, etc., for the purposes explained in this Privacy Policy.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [144:148]:
#   • We may use your information to operate our Services. We may also personalize the services we
#   • provide to you based on the information we have collected about you (for instance, we may use
#   • your IP address to display content relevant for your area). And, to enable accessibility settings
#   • functions (for you, or other users), we may convert your voice data to text.
# EU Policy Clause(s) [176:181]:
#   • We may use your information to operate our Services.
#   • We may also personalise the services we provide to you based on the information we have collected
#   • about you (for instance, we may use your IP address to display content relevant for your area) and,
#   • to enable accessibility settings functions (for you, or other users), we may convert your voice data
#   • to text.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [151:152]:
#   • may use the information to develop and optimize user interfaces or game performance.
# EU Policy Clause(s) [184:185]:
#   • may use the information to develop and optimise user interfaces or game performance.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [162:163]:
#   • We may target and personalize our marketing communications, purchase recommendations and
# EU Policy Clause(s) [195:196]:
#   • We may target and personalise our marketing communications, purchase recommendations and
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [164:165]:
#   • information we have collected about you. You may notice this personalization on the PlayStation
# EU Policy Clause(s) [197:198]:
#   • information we have collected about you. You may notice this personalisation on the PlayStation
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [168:169]:
#   • about you to personalize marketing to you, and can learn more about them in the Choices section
# EU Policy Clause(s) [201:202]:
#   • about you to personalise marketing to you and can learn more about them in the Choices section
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [182:183]:
#   • Protect your account from unauthorized access (for example by preventing access if an
# EU Policy Clause(s) [215:216]:
#   • Protect your account from unauthorised access (for example by preventing access if an
#
# --- Difference: INSERT ---
# US Policy Clause(s) [185:185]:
# EU Policy Clause(s) [218:219]:
#   • Who we share data with and where
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [192:194]:
#   • Service providers are required to adhere to this Privacy Policy, and confidentiality and security
#   • requirements.
# EU Policy Clause(s) [226:227]:
#   • Service providers are required to adhere to confidentiality and security requirements.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [197:198]:
#   • Financial organizations, such as payment details in order to complete your purchase, obtain
# EU Policy Clause(s) [230:231]:
#   • Financial organisations, such as payment details in order to complete your purchase, obtain
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [200:203]:
#   • Game publishers, such as the content you have purchased from PlayStation Store so that
#   • they can deliver that content to you in-game, and ensure your entitlement to access that
#   • content is reflected across different gaming platforms.
# EU Policy Clause(s) [233:236]:
#   • Game publishers of the content you have purchased from PlayStation Store so that they
#   • can deliver that content to you in-game, and ensure your entitlement to access that content
#   • is reflected across different gaming platforms.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [208:210]:
#   • Security and fraud partners, as appropriate to support the security of our Services, fraud
#   • prevention, or protect PI.
# EU Policy Clause(s) [241:243]:
#   • Security and fraud partners, including Sony Group, as appropriate to support the security
#   • of our Services, fraud prevention, or protect PI.
#
# --- Difference: DELETE ---
# US Policy Clause(s) [213:219]:
#   • •
#   • Sony Group, for purposes related to providing you with content, products, or services,
#   • including games, videos, music, software and software applications; community
#   • administration or development; to support various business and security processes;
#   • research and development; and so that other Sony group companies may contact you about
#   • products, services or other offerings that may be of interest to you.
# EU Policy Clause(s) [246:246]:
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [229:237]:
#   • Your PlayStation Network Online ID
#   • •
#   • "About Me" statement, avatar, language, country and gaming scores and statistics
#   • •
#   • Content you have shared
#   • You are responsible for any content you share on forums, communities, chat and messaging
#   • features. This content will be accessible to other users who can then share that information further.
#   • We recommend you consider carefully what you share and with whom you share your information.
# EU Policy Clause(s) [256:264]:
#   • Your PlayStation Network Online ID.
#   • •
#   • "About Me" statement, avatar, language, country and gaming scores and statistics.
#   • •
#   • Content you have shared.
#   • You are responsible for any content you share using blogs, chat, and messaging features. This
#   • content will be accessible to other users who can then share that information further. We
#   • recommend you consider carefully what you share and with whom you share your information.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [239:242]:
#   • Government Authorities
#   • We may share your information with police and other government authorities if we believe that it
#   • is reasonably necessary to comply with a law, regulation, or legal process, to detect, protect and
# EU Policy Clause(s) [266:269]:
#   • Government & Authorities
#   • We may share your information with police, government, and other authorities if we believe that
#   • it is reasonably necessary to comply with a law, regulation, or legal process, to detect, protect and
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [243:248]:
#   • report criminal activity. The majority of the cases in which we have shared information with police
#   • and government authorities concern their investigations into stolen devices, unauthorized use of
#   • payment methods, or moderation purposes and safety of PlayStation Network and its users. In a
#   • small number of cases, we have also provided information in response to anti-fraud or more serious
#   • criminal investigations.
# EU Policy Clause(s) [270:275]:
#   • report criminal activity. The majority of the cases in which we have shared information with police,
#   • government, and other authorities concern their investigations into stolen devices, unauthorised
#   • use of payment methods, or moderation purposes and safety of PlayStation Network and its users.
#   • In a small number of cases, we have also provided information in response to anti-fraud or more
#   • serious criminal investigations.
#
# --- Difference: INSERT ---
# US Policy Clause(s) [249:249]:
# EU Policy Clause(s) [276:277]:
#   • How we store your data and your rights
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [250:258]:
#   • We are committed to respecting children's privacy. We will not collect PI from anyone we have
#   • actual knowledge is under the age of 13, without a parent's consent. We do not share the PI of
#   • children who we have actual knowledge are under the age of 16 for delivery of advertising
#   • purposes. If you are creating an account for your child, we recommend that you and your child
#   • read our Privacy Information for Young Players to help them understand how we handle their PI
#   • and their rights over their PI.
#   • With parental consent, we will collect, use and share information collected from or about children
#   • in accordance with the practices described in this document, with the following exceptions.
# EU Policy Clause(s) [278:287]:
#   • Accounts for children between the age of 7 to 17 years old, must be created by your parent or legal
#   • guardian ("Responsible Adult"). If you are creating an account for your child, we recommend that
#   • you and your child read our Privacy Information for Young Players to help them understand how
#   • we handle their PI and their rights over their PI.
#   • If you are aged 7 - 17, you can ask your Responsible Adult to explain anything you do not
#   • understand. You can also read our Privacy Information for Young Players to help you understand
#   • how we use your information and your privacy rights over your information.
#   • We will collect, use and share information collected from or about children in accordance with the
#   • practices described in this document, with the following exceptions.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [260:267]:
#   • A parent only needs to provide limited information about their child (an email address and
#   • date-of-birth) to create an Account for their child. Providing gender is optional.
#   • •
#   • Only with the parent's approval to create an Account for the child, can a child add their
#   • address.
#   • •
#   • The spending limit of the Account for your child is set by the associated parent's Account.
# EU Policy Clause(s) [289:298]:
#   • A Responsible Adult only needs to provide limited information about their child (an email
#   • address and date-of-birth) to create an Account for their child. Providing gender is
#   • optional.
#   • •
#   • Only with the Responsible Adult’s approval to create an Account for the child, can a child
#   • add their address.
#   • •
#   • The spending limit of the Account for your child is set by the associated Responsible
#   • Adult’s Account.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [269:295]:
#   • A parent can control, through the “Free Communication” setting on their child's Account,
#   • their child's ability to use (and share PI through) text chat, voice chat, video chat, and other
#   • messaging features from communicating directly with other users in games, apps or via
#   • system software features. Please note that a child's Account can still (1) Send and receive
#   • predetermined text messages created by a game or app, (2) Create and see other users' in-
#   • game character names, designs, and clan titles, (3) Use communication services via an
#   • Internet browser unless specifically disabled, and (4) Communicate via system messaging
#   • on PS3 and PS Vita.
#   • •
#   • A parent can control their child's ability to post or view user-generated content, including
#   • photos, videos, drawings, and content imported from outside sources (any of which might
#   • contain PI) through the user-generated content control. This will not prevent video capture
#   • of a child Account user's online gameplay.
#   • •
#   • A parent can agree to our collection and use of their child's PI without consenting to our
#   • disclosure to third parties, except when the disclosure is inherent to the Services we are
#   • providing.
#   • When a parent allows their child's Account to participate in games, chat or user-generated content
#   • features, they also consent to SIE sharing information with the publishers of the games,
#   • applications, or services that incorporate those features and the collection of information entered
#   • into such features by the child's Account (e.g. typing text into the chat feature).
#   • If you discover your child under the age of 13 has provided PI to us without your consent, once
#   • we verify you are the child's parent, we will promptly: (a) provide direct notice to you indicating
#   • what, if any PI of your child has been collected and how it has been used or disclosed; (b) remove
#   • and cease the use of your child's PI or other information from our database and (c) by notice to
#   • you, confirm compliance with the foregoing.
# EU Policy Clause(s) [300:323]:
#   • A Responsible Adult can control, through the “Free Communication” setting on their
#   • child's Account, their child's ability to use (and share PI through) text chat, voice chat,
#   • video chat, and other messaging features from communicating directly with other users in
#   • games, apps or via system software features. Please note that a child's Account can still (1)
#   • send and receive predetermined text messages created by a game or app, (2) create and see
#   • other users' in-game character names, designs, and clan titles, and (3) use communication
#   • services via an Internet browser unless specifically disabled.
#   • •
#   • A Responsible Adult can control their child's ability to post or view user-generated content,
#   • including photos, videos, drawings, and content imported from outside sources (any of
#   • which might contain PI) through the user-generated content control. This will not prevent
#   • video capture of a child Account user's online gameplay.
#   • •
#   • A Responsible Adult can agree to our collection and use of their child's PI without
#   • consenting to our disclosure to third parties, except when the disclosure is inherent to the
#   • Services we are providing.
#   • When a Responsible Adult allows their child's Account to participate in games, chat or user-
#   • generated content features, they also allow consent to SIE sharing information with the publishers
#   • of the games, applications, or services that incorporate those features and the collection of
#   • information entered into such features by the child's Account (e.g. typing text into the chat feature).
#   • If you discover your child under the age of 18 has created an Account, once we verify you are the
#   • child's Responsible Adult parent, we will promptly give access and control of the child’s account
#   • to you.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [308:310]:
#   • We seek to maintain appropriate technical and organizational security measures that conform to
#   • industry standards to help protect your information against unauthorized or accidental disclosure,
# EU Policy Clause(s) [336:338]:
#   • We seek to maintain appropriate technical and organisational security measures that conform to
#   • industry standards to help protect your information against unauthorised or accidental disclosure,
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [319:326]:
#   • you become aware of any unauthorized use of your accounts or other security breaches.
#   • We may retain information about you as long as it is necessary for us to fulfill the purposes outlined
#   • in this policy. In addition, we may retain your information for an additional period as is permitted
#   • or required to, among other things, comply with our legal obligations, resolve disputes, and enforce
#   • agreements. Where required by applicable law, we shall delete your information when the
#   • information is no longer necessary or requested to do so. Even if we delete your information from
#   • active databases, the information may remain on backup or archival media as well as other
# EU Policy Clause(s) [347:354]:
#   • you become aware of any unauthorised use of your accounts or other security breaches.
#   • We may retain information about you as long as it is necessary for us to fulfil the purposes outlined
#   • in this Privacy Policy. In addition, we may retain your information for an additional period as is
#   • permitted or required to, among other things, comply with our legal obligations, resolve disputes,
#   • and enforce agreements. Where required by applicable law, we shall delete your information when
#   • the information is no longer necessary or requested to do so. Even if we delete your information
#   • from active databases, the information may remain on backup or archival media as well as other
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [331:343]:
#   • that your information is up-to-date. Among others, you have the following choices:
#   • •
#   • Personalized content and marketing: Whether we may use the information we have
#   • collected about you to personalize advertising and purchase recommendations. Note that
#   • we will always slightly customize what you see (e.g. to avoid displaying content you've
#   • already purchased from the PlayStation Store), and some older devices (e.g. PS3/Vita),
#   • apps and games may still show some commercial personalization.
#   • •
#   • Personalized communications: Whether we may use the information we have collected, to
#   • personalize emails and notifications.
#   • •
#   • Limited Data/Service Data and Full Data/Advanced Data collection: Whether we may
# EU Policy Clause(s) [359:371]:
#   • that your information is up to date. Among others, you have the following choices:
#   • •
#   • Personalised content and marketing: Whether we may use the information we have
#   • collected about you to personalise advertising and purchase recommendations. Note that
#   • we will always slightly customise what you see (e.g. to avoid displaying content you've
#   • already purchased from the PlayStation Store), and some older devices, apps and games
#   • may still show some commercial personalisation.
#   • •
#   • Personalised communications: Whether we may use the information we have collected, to
#   • personalise emails and notifications.
#   • •
#   • Limited Data/Service Data and Full Data/Additional Data collection: Whether we may
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [352:356]:
#   • Do Not Track (DNT)
#   • "Do Not Track" is an internet browser setting regarding tracking. As there are currently no agreed
#   • upon standards for the DNT signals or how to respond to them, we adhere to the standards set out
#   • in this Privacy Policy.
# EU Policy Clause(s) [380:385]:
#   • •
#   • Collection of cookies: You can manage cookies that are not strictly necessary for the
#   • provision of our websites, this will also limit when we can recognise your visits to our
#   • websites and target and personalise the advertising and commercial purchase
#   • recommendations displayed on those websites.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [357:373]:
#   • In addition to the rights described below, you can also access, amend or delete some information
#   • through your Account Settings page.
#   • •
#   • Request to Access and Correct: You have the right to request that we inform you of the PI
#   • we hold about you, as well as to request the correction of any inaccurate information about
#   • you.
#   • •
#   • Right of Access: You have the right to request that we inform you of the PI we have
#   • collected, used and shared about you, and to obtain a copy of it.
#   • •
#   • Right of Deletion: You have the right to request that we delete the PI we have collected or
#   • retained about you in some circumstances as defined by law. To request removal of certain
#   • of your PI from a blog, forum, or message board, please contact us as described in the
#   • Contact Us section above. Following your request for deletion, please be aware that the
#   • information that we collect about you may still be retained for legal, accounting, business
#   • continuity (backup), anti-fraud and community reasons.
# EU Policy Clause(s) [386:426]:
#   • You can access, amend or delete some information through your Account settings. You can also
#   • exercise the rights described below by contacting us at www.playstation.com/data-subject-request.
#   • We reserve the right to deny your requests if we cannot verify your identity.
#   • •
#   • Right of Access and Portability: You have the right to request certain information about the
#   • processing of your PI and to be provided with a copy of your PI. To download a copy of
#   • key PI that we process, sign-in to your Account on www.playstation.com and navigate to
#   • [Account Settings] > [Privacy Settings] > [Data Access Requests].
#   • •
#   • Right of Erasure: You have the right to request that we delete the PI we have collected or
#   • retained about you in some circumstances as defined by law.  To request removal of certain
#   • of your PI from a blog or chat, please contact us as described in the Contact Us section
#   • below. Following your request for deletion, please be aware that the information that we
#   • collect about you may still be retained for legal, accounting, business continuity (backup),
#   • anti-fraud and community reasons. You can close your account for PlayStation Network by
#   • contacting PlayStation Support. Information collected from older games and apps may not
#   • be integrated with account closure. Following your account closure request, please be
#   • aware that the information that we collect about you may still be retained for legal,
#   • accounting, business continuity (backup), anti-fraud and community reasons. If you have
#   • accounts with other Sony group companies you will need to contact those companies
#   • separately
#   • to
#   • close
#   • those
#   • accounts.
#   • For
#   • more
#   • information,
#   • visit
#   • https://www.sony.co.uk/mysony.
#   • •
#   • Right of rectification: You have the right to rectify your information, restrict processing,
#   • and object to the use of your PI in some circumstances as defined by law.
#   • •
#   • Right to Object: You have the right to object to the processing of your PI in certain
#   • circumstances. For example, you have the right to object to the use of your PI for direct
#   • marketing purposes.
#   • •
#   • Right to Restrict: You have the right to restrict the processing of your PI in certain
#   • circumstances.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [377:404]:
#   • To
#   • make
#   • a
#   • Request
#   • to
#   • Access
#   • or
#   • Deletion,
#   • please
#   • visit https://ps-
#   • support.playstation.com/s/consumer-privacy?language=en_US&locale=en-us,
#   • or
#   • contact
#   • Consumer Services toll-free at 1-800-345-7669. After you submit a request, we will require you
#   • to confirm your request, and verify your identity by requesting details of your account, devices,
#   • payment instruments or past transactions. We reserve the right to deny your requests if we cannot
#   • verify your identity.
#   • Right to Opt-Out of Share
#   • We may share data about your activities related to PlayStation services, websites, and apps with
#   • third parties to provide ads that are more personalized to you on third-party platforms. You may
#   • opt-out of our sharing of your personal information by visiting the link below and completing the
#   • web form: https://www.playstation.com/en-us/legal/third-party-ads/.
#   • Alternatively, you may also opt-out by sending an email to sie-privacy@sony.com and providing
#   • the email address associated with your PSN account.
#   • This Privacy Policy is made available in an accessible format that is compatible with ADA
#   • compliant web browsers.  For an alternative accessible PDF of the Privacy Policy please contact
#   • 1-800-345-7669.
# EU Policy Clause(s) [430:432]:
#   • For an alternative accessible PDF of the Privacy Policy please contact us using the information in
#   • the Contact Us section of this Privacy Policy.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [405:434]:
#   • ESRB Privacy Certified
#   • This
#   • Privacy
#   • Statement
#   • and
#   • the
#   • confirmation
#   • page
#   • at www.esrb.org/confirm/siea-
#   • confirmation.aspx or accessed by clicking the seal in the footer of any page of playstation.com)
#   • confirms that SIE is a valid licensee and participating member in the Entertainment Software
#   • Rating Board's Privacy Certified Program. We have undertaken this privacy initiative and our
#   • websites have been reviewed and certified by ESRB Privacy Online to meet established online
#   • information collection and use practices. As part of the privacy program, we are subject to frequent
#   • audits of our sites and other enforcement and accountability mechanisms administered
#   • independently by ESRB.
#   • How to Contact Us About this Privacy Policy
#   • For further information on our Privacy Policy, or how users can review or change their information,
#   • please contact us at:
#   • - By Phone at:
#   • 1-800-345-7669
#   • - By Mail at:
#   • SONY INTERACTIVE ENTERTAINMENT CONSUMER SERVICES DEPARTMENT
#   • 2207 BRIDGEPOINTE PARKWAY
#   • SAN MATEO, CALIFORNIA, 94404
#   • Online: www.playstation.com/support
#   • SIE is a licensee of ESRB's Privacy Certified Program. If you believe that we have not responded
#   • to your privacy-related inquiry or your inquiry has not been satisfactorily addressed, please contact
#   • ESRB Privacy Certified at www.esrb.org/privacy/contact.aspx.
# EU Policy Clause(s) [433:473]:
#   • If you have a concern about our handling of your PI, please get in contact with us first so we can
#   • try to resolve your query using the details in the Contact Us section of this Privacy Policy. You can
#   • also contact our Data Protection Officer via email at siee.dpo@sony.com.
#   • If however you feel we have not dealt with your concern and/or that we are failing to meet our
#   • legal obligations, you can report this to your local data protection regulator or the Information
#   • Commissioner's Office ("ICO") in the United Kingdom. More information on reporting a concern
#   • to the ICO can be found at https://ico.org.uk/.
#   • Contact Us
#   • Please contact us for further information about our Privacy Policy or our processing of your PI, by
#   • either of the following methods:
#   • Post:
#   • Data
#   • Protection
#   • Office
#   • Sony Interactive Entertainment Europe Limited / Sony Interactive Entertainment Network Europe
#   • Limited
#   • /
#   • Sony
#   • Interactive
#   • Entertainment
#   • Direct
#   • Europe
#   • Limited
#   • 10
#   • Great
#   • Marlborough
#   • Street
#   • London
#   • United
#   • Kingdom
#   • W1F 7LP
#   • Online:
#   • You can contact us by using our web form:
#   • www.playstation.com/data-subject-request
#   • Sony Interactive Entertainment Europe Limited, Sony Interactive Entertainment Network Europe
#   • Limited, and Sony Interactive Entertainment Direct Europe Limited are registered in England
#   • under company numbers: 03277793, 06020283, and 03754597.
#   • We have appointed Özdağıstanli Ekici Avukatlık Ortaklığı as our Turkish Data Controller
#   • Representative. If you are located in Turkey, you can contact our Turkish Data Controller
#   • Representative by email at info@iptech-legal.com.
#
# --- Difference: REPLACE ---
# US Policy Clause(s) [435:439]:
#   • We may revise this Privacy Policy at any time and we will update this Policy with any revisions.
#   • By continuing to access or use the Services after those changes become effective, you acknowledge
#   • and accept that PI will be handled in accordance with the revised Privacy Policy.
#   • Last Revised: 2023-06
# EU Policy Clause(s) [474:478]:
#   • We may revise this Privacy Policy at any time and we will update this Privacy Policy with any
#   • revisions. By continuing to access or use the Services after those changes become effective, you
#   • acknowledge and accept that PI will be handled in accordance with the revised Privacy Policy.
#   • Version 9.2 (January 2024)

# %%
# Threshold for similarity (0.8 = 80%)
SIMILARITY_THRESHOLD = 0.8

print("\n--- SIMILAR CLAUSES (US vs EU) ---\n")

for us_clause in clauses_us:
    for eu_clause in clauses_eu:
        ratio = difflib.SequenceMatcher(None, us_clause, eu_clause).ratio()
        if ratio >= SIMILARITY_THRESHOLD:
            print(f"US: {us_clause}")
            print(f"EU: {eu_clause}")
            print(f"Similarity: {round(ratio*100, 2)}%\n")
            break  # Only show first match per US clause (optional)
# Out:
# --- SIMILAR CLAUSES (US vs EU) ---
#
# US: About Us and this Policy
# EU: About Us and this Policy
# Similarity: 100.0%
#
# US: This Privacy Policy explains when we collect information about you, including Personal
# EU: This Privacy Policy explains when we collect information about you, including Personal
# Similarity: 100.0%
#
# US: Information (“PI”), what we collect, why we collect it, how we use it, who we share it with, where
# EU: Information (“PI”), what we collect, why we collect it, how we use it, who we share it with, where
# Similarity: 100.0%
#
# US: it is processed, how we handle it and your choices and legal rights associated with this information.
# EU: it is processed, how we handle it and your choices and legal rights associated with this information.
# Similarity: 100.0%
#
# US: Scope of this Policy
# EU: Scope of this Policy
# Similarity: 100.0%
#
# US: controls the information collected when you interact with PlayStation through our Services.
# EU: controls the information collected when you interact with PlayStation through our websites,
# Similarity: 94.51%
#
# US: Contact Us
# EU: Contact Us
# Similarity: 100.0%
#
# US: Information That We Collect or Receive
# EU: Information That We Collect or Receive
# Similarity: 100.0%
#
# US: We collect and receive information from and about you by different means as described below.
# EU: We collect and receive information from and about you by different means as described below.
# Similarity: 100.0%
#
# US: Information You Provide to Us
# EU: Information You Provide to Us
# Similarity: 100.0%
#
# US: We collect the information that you directly provide to us, such as when you enter it on our website,
# EU: We collect the information that you directly provide to us, such as when you enter it on our website,
# Similarity: 100.0%
#
# US: or include it in an email that you send to us. This type of collection often occurs through our
# EU: or include it in an email that you send to us. This type of collection often occurs through our
# Similarity: 100.0%
#
# US: business support processes, such as:
# EU: business support processes, such as:
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Registration or PlayStation Network Account (“Account”) Creation Processes, where we
# EU: Registration or PlayStation Network Account (“Account”) Creation Processes, where we
# Similarity: 100.0%
#
# US: ask you to provide information such as: Contact info (e.g. name, email or physical address,
# EU: ask you to provide information such as: Contact information (e.g. name, email or physical
# Similarity: 91.11%
#
# US: country, or phone number); Account Administration Info (e.g. user name, password, or
# EU: address, country, or phone number); Account Administration information (e.g. user name,
# Similarity: 81.87%
#
# US: security questions); Billing Information (e.g. credit card or other payment number, billing
# EU: password, or security questions); Billing information (e.g. credit card or other payment
# Similarity: 82.68%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Purchase Processes, where we may ask you to provide additional billing info to process
# EU: Purchase Processes, where we may ask you to provide additional billing info to process
# Similarity: 100.0%
#
# US: payment.
# EU: payment.
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Technical and Customer Support Processes, where we may ask you to provide contact info
# EU: Technical and Customer Support Processes, where we may ask you to provide contact
# Similarity: 97.01%
#
# US: and information related to the issue you are contacting us about. We may also record calls
# EU: information and information related to the issue you are contacting us about. We may also
# Similarity: 86.03%
#
# US: you make to PlayStation Support.
# EU: record calls you make to PlayStation Support.
# Similarity: 83.12%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Other business processes, where we may ask you to provide information such as name,
# EU: Other business processes, where we may ask you to provide information such as name,
# Similarity: 100.0%
#
# US: email address, and Account ID if you participate in market research surveys, beta and other
# EU: email address, and Account ID if you participate in market research surveys, beta and other
# Similarity: 100.0%
#
# US: user testing research, competitions, promotions or events or agree to receive marketing
# EU: user testing research, competitions, promotions or events or agree to receive marketing
# Similarity: 100.0%
#
# US: information from us.
# EU: information from us.
# Similarity: 100.0%
#
# US: In addition, we collect the information that you provide by entering it into certain Service features.
# EU: In addition, we collect the information that you provide by entering it into certain Service features.
# Similarity: 100.0%
#
# US: For example, when you want to post in a forum, you provide us the content for the post (which
# EU: For example, when you want to post in a blog, you provide us the content for the blog post (which
# Similarity: 93.68%
#
# US: could contain PI which we collect and then display for you on the forum). Likewise, when you use
# EU: could contain PI which we collect and then display for you on the blog). Likewise, when you use
# Similarity: 96.34%
#
# US: other features such as voice or text messaging, blogs, surveys, user-generated content, activity
# EU: other features such as voice or text messaging, blogs, surveys, user-generated content, activity
# Similarity: 100.0%
#
# US: streams, or social media, we may first collect the information you enter into the feature.
# EU: streams, or social media, we may first collect the information you enter into the feature.
# Similarity: 100.0%
#
# US: Please make sure that any personal details which you provide are accurate and current. We will
# EU: Please make sure that any personal details which you provide are accurate and current. We will
# Similarity: 100.0%
#
# US: send any important information relating to your Account to you using the contact information you
# EU: send any important information relating to your Account to you using the contact information you
# Similarity: 100.0%
#
# US: provide (including Account security and privacy notices). You can check and update some of the
# EU: provide (including Account security and privacy notices). You can check and update some of the
# Similarity: 100.0%
#
# US: information you have provided to us any time via Account Management.
# EU: information you have provided to us any time via Account Management.
# Similarity: 100.0%
#
# US: Automatic Information Collection
# EU: Automatic Information Collection
# Similarity: 100.0%
#
# US: We may also automatically or passively collect information about your use of our Services, see the
# EU: We may also automatically or passively collect information about your use of our Services, see the
# Similarity: 100.0%
#
# US: sub-sections below for a list of categories by sources of such information.
# EU: sub-sections below for a list of categories by sources of such information.
# Similarity: 100.0%
#
# US: Consoles and other devices
# EU: Consoles and other devices
# Similarity: 100.0%
#
# US: Each time you use a PlayStation console or a PlayStation app on a PlayStation console or other
# EU: Each time you use a PlayStation console or a PlayStation app on a PlayStation console or other
# Similarity: 100.0%
#
# US: devices (such as a mobile phone or PC), we may automatically collect information about your use
# EU: devices (such as a mobile phone or PC), we may automatically collect information about your use
# Similarity: 100.0%
#
# US: of that device and app. If you sign into an Account, we may combine it with other information we
# EU: of that device and app. If you sign into an Account, we may combine it with other information we
# Similarity: 100.0%
#
# US: have for that Account.
# EU: have for that Account.
# Similarity: 100.0%
#
# US: The information that we collect from devices may include:
# EU: The information that we collect from devices may include:
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Device identifiers such as your PlayStation console ID, mobile device IDs, cookie IDs, or
# EU: Device identifiers such as your PlayStation console ID, mobile device IDs, cookie IDs, or
# Similarity: 100.0%
#
# US: serial numbers
# EU: serial numbers.
# Similarity: 96.55%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Network identifiers such as your IP address and MAC address
# EU: Network identifiers such as your IP address and MAC address.
# Similarity: 99.16%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Account authentication tokens that avoid you having to log in repeatedly
# EU: Account authentication tokens that avoid you having to log in repeatedly.
# Similarity: 99.31%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Content and ads downloaded to your device for the online services that you access
# EU: Content and ads downloaded to your device for the online services that you access.
# Similarity: 99.39%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Your current and recent locations (e.g. on PS Vita)
# EU: Your current and recent locations.
# Similarity: 80.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Trophies, scores and rankings achieved online and offline
# EU: Trophies, scores and rankings achieved online and offline.
# Similarity: 99.13%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Information about the device you are using, any connected peripherals (such as controllers
# EU: Information about the device you are using, any connected peripherals (such as controllers
# Similarity: 100.0%
#
# US: and VR headsets) and how you have configured them
# EU: and VR headsets) and how you have configured them.
# Similarity: 98.99%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Information about how you use the software installed on your device (which may include
# EU: Information about how you use the software installed on your device (which may include
# Similarity: 100.0%
#
# US: information about the use of the software offline), such as date and time of use, what games
# EU: information about the use of the software offline), such as date and time of use, what games
# Similarity: 100.0%
#
# US: or music you play, what content you browse, share or download, what services you access
# EU: or music you play, what content you browse, share or download, what services you access
# Similarity: 100.0%
#
# US: and for how long, including how often you use chat and other communication applications
# EU: and for how long, including how often you use chat and other communication applications.
# Similarity: 99.43%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: The actions you take within games or apps published by SIE (e.g. what obstacle you jump
# EU: The actions you take within games or apps published by SIE (e.g. what obstacle you jump
# Similarity: 100.0%
#
# US: over and what levels you reach)
# EU: over and what levels you reach).
# Similarity: 98.41%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Software errors and load times details, and if you have the "Report System Software Errors
# EU: Software errors and load times details, and if you have the "Report System Software Errors
# Similarity: 100.0%
#
# US: Automatically" setting turned on, detailed information about the crash, including
# EU: Automatically" setting turned on, detailed information about the crash, including
# Similarity: 100.0%
#
# US: screenshots and video captured before the crash
# EU: screenshots and video captured before the crash.
# Similarity: 98.95%
#
# US: On a device or app basis, depending on your region, and for games released after March 2018, you
# EU: On a device or app basis, depending on your region, and for games released after March 2018, you
# Similarity: 100.0%
#
# US: may be provided with choices that control our collection of information. For further information
# EU: may be provided with choices that control our collection of information. For further information
# Similarity: 100.0%
#
# US: on these options, refer to the Choices section of this Privacy Policy below.
# EU: on these options, refer to the Choices section of this Privacy Policy below.
# Similarity: 100.0%
#
# US: PlayStation Network and Store
# EU: PlayStation Network and Store
# Similarity: 100.0%
#
# US: Each time you sign into PlayStation Network and access our Services, we may automatically:
# EU: Each time you sign into PlayStation Network and access our Services, we may automatically:
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Collect information about your use of PlayStation Network Services on your device.
# EU: Collect information about your use of PlayStation Network Services on your device.
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Log your activity on our PlayStation Network servers. For example, we may receive device
# EU: Log your activity on our PlayStation Network servers. For example, we may receive device
# Similarity: 100.0%
#
# US: and Account identifiers, such as your PlayStation Network Online ID and Account ID. We
# EU: and Account identifiers, such as your PlayStation Network Online ID and Account ID. We
# Similarity: 100.0%
#
# US: may also receive details of: the content, advertisements, and other information your devices
# EU: may also receive details of: the content, advertisements, and other information your devices
# Similarity: 100.0%
#
# US: request and receive from our servers (such as store content, trophies, and friends lists) and
# EU: request and receive from our servers (such as store content, trophies, and friends lists) and
# Similarity: 100.0%
#
# US: when you receive and interact with them; what content and apps you add to your 'basket'
# EU: when you receive and interact with them; what content and apps you add to your 'basket'
# Similarity: 100.0%
#
# US: in our Store; and what you purchase.
# EU: in our Store; and what you purchase.
# Similarity: 100.0%
#
# US: Games
# EU: Games
# Similarity: 100.0%
#
# US: Each time you play a game developed and/or published by us or another Sony Interactive
# EU: Each time you play a game developed and/or published by us or another Sony Interactive
# Similarity: 100.0%
#
# US: Entertainment company we may automatically:
# EU: Entertainment company we may automatically:
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Collect information about your use of that game on your device (including for offline
# EU: Collect information about your use of that game on your device (including for offline
# Similarity: 100.0%
#
# US: games, which may include information about the use of the game offline).
# EU: games, which may include information about the use of the game offline).
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Log your activity on our game servers. For example, we may receive device and Account
# EU: Log your activity on our PlayStation Network servers. For example, we may receive device
# Similarity: 82.08%
#
# US: identifiers, such as PlayStation Network Online ID, information about how you use our
# EU: identifiers, such as PlayStation Network Online ID, information about how you use our
# Similarity: 100.0%
#
# US: online games, and which players you play against.
# EU: online games, and which players you play against.
# Similarity: 100.0%
#
# US: Websites, Marketing, and Advertising
# EU: Websites, Marketing, and Advertising
# Similarity: 100.0%
#
# US: Each time you visit our websites or receive and interact with our marketing communications and
# EU: Each time you visit our websites or receive and interact with our marketing communications and
# Similarity: 100.0%
#
# US: advertising on our and third-party websites and services, we may automatically log your activity
# EU: advertising on our and third-party websites and services, we may automatically log your activity
# Similarity: 100.0%
#
# US: on web, emails, or advertising and marketing servers we control through cookies (small
# EU: on web, emails, or advertising and marketing servers we control through cookies (small
# Similarity: 100.0%
#
# US: information files placed on a hard drive), web beacons, tracking pixels, browser configuration
# EU: information files placed on a hard drive), web beacons, tracking pixels, browser configuration
# Similarity: 100.0%
#
# US: details (e.g. browser type, list of installed plugins and list of installed fonts), and embedded scripts
# EU: details (e.g. browser type, list of installed plugins and list of installed fonts), and embedded scripts
# Similarity: 100.0%
#
# US: (programming code that is temporarily downloaded onto a device).
# EU: (programming code that is temporarily downloaded onto a device) and, website personalisation
# Similarity: 80.77%
#
# US: Information We Receive from Third Parties
# EU: Information We Receive from Third Parties
# Similarity: 100.0%
#
# US: We may receive information, including the following, from third party sources and combine it with
# EU: We may receive information, including the following, from third party sources and combine it with
# Similarity: 100.0%
#
# US: information we already directly collect from you. We will handle the information in accordance
# EU: information we already directly collect from you. We will handle the information in accordance
# Similarity: 100.0%
#
# US: with this Privacy Policy.
# EU: with this Privacy Policy.
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Game, social media, or other information, from those third parties or services you link your
# EU: Game, social media, or other information, from those third parties or services you link your
# Similarity: 100.0%
#
# US: Account with, or who provide information to power PlayStation Network features.
# EU: Account with, or who provide information to power PlayStation Network features.
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Information from other users, for example if those users have given us access to their
# EU: Information from other users, for example if those users have given us access to their
# Similarity: 100.0%
#
# US: profiles and if you are one of their connections, or information about you is otherwise made
# EU: profiles and if you are one of their connections, or information about you is otherwise made
# Similarity: 100.0%
#
# US: accessible to us by them.
# EU: accessible to us by them.
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Information from third-parties as appropriate given our relationship, for example from anti-
# EU: Information from third parties as appropriate given our relationship, for example from anti-
# Similarity: 98.91%
#
# US: fraud service providers we might obtain fraud risk scores; from law enforcement or
# EU: fraud service providers we might obtain fraud risk scores; from law enforcement or
# Similarity: 100.0%
#
# US: partners, we might obtain IP addresses and details of suspected unlawful or malicious
# EU: partners, we might obtain IP addresses and details of suspected unlawful or malicious
# Similarity: 100.0%
#
# US: activity.
# EU: activity.
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Card account update information provided by your bank to help keep your payment cards
# EU: Card account update information provided by your bank to help keep your payment cards
# Similarity: 100.0%
#
# US: up to date on your Account. Following any update, we will continue to charge the
# EU: up to date on your Account. Following any update, we will continue to charge the
# Similarity: 100.0%
#
# US: applicable payment methods to any purchases you make unless you notify us otherwise.
# EU: applicable payment methods to any purchases you make unless you notify us otherwise.
# Similarity: 100.0%
#
# US: Information Use
# EU: Information Use
# Similarity: 100.0%
#
# US: This section explains how we may use the information we collect about you. We may combine
# EU: This section explains how we may use the PI we collect about you.
# Similarity: 81.82%
#
# US: Services
# EU: Services.
# Similarity: 94.12%
#
# US: Development
# EU: Development
# Similarity: 100.0%
#
# US: We use the information we collect to understand, improve and enhance our existing Services, your
# EU: We use the information we collect to understand, improve and enhance our existing Services, your
# Similarity: 100.0%
#
# US: experiences with them, and our business operations, and to develop new ones. For example, we
# EU: experiences with them, and our business operations, and to develop new ones. For example, we
# Similarity: 100.0%
#
# US: may use the information to develop and optimize user interfaces or game performance.
# EU: may use the information to develop and optimise user interfaces or game performance.
# Similarity: 98.81%
#
# US: Moderation and Safety
# EU: Moderation and Safety
# Similarity: 100.0%
#
# US: We cannot monitor the whole of PlayStation Network and make no commitment to do so.
# EU: We cannot monitor the whole of PlayStation Network and make no commitment to do so.
# Similarity: 100.0%
#
# US: However, we reserve the right in our sole discretion to monitor (including through the use of
# EU: However, we reserve the right in our sole discretion to monitor (including through the use of
# Similarity: 100.0%
#
# US: technology that automatically detects images, text, and URLs that breach our Terms of Service)
# EU: technology that automatically detects images, text, and URLs that breach our Terms of Service)
# Similarity: 100.0%
#
# US: and record your online activity and communication throughout PlayStation Network and to remove
# EU: and record your online activity and communication throughout PlayStation Network and to remove
# Similarity: 100.0%
#
# US: and/or delete any content. We may use the information we collect (as described above) to detect
# EU: and/or delete any content. We may use the information we collect (as described above) to detect
# Similarity: 100.0%
#
# US: breaches and enforce our PlayStation Network Terms of Service, Software Usage Terms, System
# EU: breaches and enforce our PlayStation Network Terms of Service, Software Usage Terms, System
# Similarity: 100.0%
#
# US: Software License Agreements, any other terms of service you have agreed to and any rules or
# EU: Software License Agreements, any other terms of service you have agreed to and any rules or
# Similarity: 100.0%
#
# US: codes of conduct applicable to your use of PlayStation Network.
# EU: codes of conduct applicable to your use of PlayStation Network.
# Similarity: 100.0%
#
# US: Marketing and Advertising
# EU: Websites, Marketing, and Advertising
# Similarity: 81.97%
#
# US: We may target and personalize our marketing communications, purchase recommendations and
# EU: We may target and personalise our marketing communications, purchase recommendations and
# Similarity: 98.86%
#
# US: advertisements that we display on our and third-party websites and services based on the
# EU: advertisements that we display on our and third-party websites and services based on the
# Similarity: 100.0%
#
# US: information we have collected about you. You may notice this personalization on the PlayStation
# EU: information we have collected about you. You may notice this personalisation on the PlayStation
# Similarity: 98.95%
#
# US: Store (whether via console, website or in-game), in marketing communications, or when you visit
# EU: Store (whether via console, website or in-game), in marketing communications, or when you visit
# Similarity: 100.0%
#
# US: our and third-party websites (such as social network sites) that show purchase recommendations
# EU: our and third-party websites (such as social network sites) that show purchase recommendations
# Similarity: 100.0%
#
# US: or advertisements from us.  You have options to control our use of information we have collected
# EU: or advertisements from us.  You have options to control our use of information we have collected
# Similarity: 100.0%
#
# US: about you to personalize marketing to you, and can learn more about them in the Choices section
# EU: about you to personalise marketing to you and can learn more about them in the Choices section
# Similarity: 98.41%
#
# US: of this Privacy Policy.
# EU: with this Privacy Policy.
# Similarity: 87.5%
#
# US: Legal and Compliance
# EU: Legal and Compliance
# Similarity: 100.0%
#
# US: We may use the information we collect for auditing, compliance and legal purposes (for example,
# EU: We may use the information we collect for auditing, compliance and legal purposes (for example,
# Similarity: 100.0%
#
# US: protecting the rights and property of Sony, its partners and customers).
# EU: protecting the rights and property of Sony, its partners and customers).
# Similarity: 100.0%
#
# US: Security
# EU: Security
# Similarity: 100.0%
#
# US: In order to help protect you and others, we may use the information we collect and receive in order
# EU: In order to help protect you and others, we may use the information we collect and receive in order
# Similarity: 100.0%
#
# US: to:
# EU: to:
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Identify fraudulent activities and transactions.
# EU: Identify fraudulent activities and transactions.
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Prevent abuse of and investigate and/or prosecute any potential threat to or misuse of our
# EU: Prevent abuse of and investigate and/or prosecute any potential threat to or misuse of our
# Similarity: 100.0%
#
# US: Services.
# EU: Services.
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Protect your account from unauthorized access (for example by preventing access if an
# EU: Protect your account from unauthorised access (for example by preventing access if an
# Similarity: 98.82%
#
# US: attempt is made to log-in from a new location).
# EU: attempt is made to log-in from a new location).
# Similarity: 100.0%
#
# US: Information Sharing and Transfers
# EU: Information Sharing and Transfers
# Similarity: 100.0%
#
# US: This section explains how we may share the information we collect with third parties that provide
# EU: This section explains how we may share the information we collect with third parties that provide
# Similarity: 100.0%
#
# US: services to us or provide games and apps on PlayStation Network that you use. We do not and will
# EU: services to us or provide games and apps on PlayStation Network that you use. We do not and will
# Similarity: 100.0%
#
# US: not accept money in exchange for sharing PI. We may share your information with the following
# EU: not accept money in exchange for sharing PI. We may share your information with the following
# Similarity: 100.0%
#
# US: recipients and for the following purposes.
# EU: recipients and for the following purposes.
# Similarity: 100.0%
#
# US: Service Providers
# EU: Service Providers
# Similarity: 100.0%
#
# US: We share information with service providers to SIE, who are persons or companies that provide
# EU: We share information with service providers to SIE, who are persons or companies that provide
# Similarity: 100.0%
#
# US: services which may include handling PI for any of the purposes described in this Privacy Policy.
# EU: services which may include handling PI for any of the purposes described in this Privacy Policy.
# Similarity: 100.0%
#
# US: Partners
# EU: Partners
# Similarity: 100.0%
#
# US: We may share information with the following partners:
# EU: We may share information with the following partners:
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Financial organizations, such as payment details in order to complete your purchase, obtain
# EU: Financial organisations, such as payment details in order to complete your purchase, obtain
# Similarity: 98.9%
#
# US: payment and carry out credit and anti-fraud checks.
# EU: payment and carry out credit and anti-fraud checks.
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Game publishers, such as the content you have purchased from PlayStation Store so that
# EU: Game publishers of the content you have purchased from PlayStation Store so that they
# Similarity: 91.23%
#
# US: they can deliver that content to you in-game, and ensure your entitlement to access that
# EU: can deliver that content to you in-game, and ensure your entitlement to access that content
# Similarity: 92.74%
#
# US: content is reflected across different gaming platforms.
# EU: is reflected across different gaming platforms.
# Similarity: 92.16%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Other service, application or website providers, for operational purposes, or for additional
# EU: Other service, application or website providers, for operational purposes, or for additional
# Similarity: 100.0%
#
# US: purposes, with your permission (such as when you link your Account to your account with
# EU: purposes, with your permission (such as when you link your Account to your account with
# Similarity: 100.0%
#
# US: them).
# EU: them).
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Advertising and promotional partners, with whom we are jointly delivering services or
# EU: Advertising and promotional partners, with whom we are jointly delivering services or
# Similarity: 100.0%
#
# US: features, such as sweepstakes, contests, promotions, or advertising.
# EU: features, such as sweepstakes, contests, promotions, or advertising.
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Business transfer partners, in connection with the negotiation and sale of the applicable
# EU: Business transfer partners, in connection with the negotiation and sale of the applicable
# Similarity: 100.0%
#
# US: business, a portion of the business, or certain stock and/or assets, or a corporate merger,
# EU: business, a portion of the business, or certain stock and/or assets, or a corporate merger,
# Similarity: 100.0%
#
# US: consolidation, restructuring, or other corporate change including, without limitation,
# EU: consolidation, restructuring, or other corporate change including, without limitation,
# Similarity: 100.0%
#
# US: during the course of any due diligence process.
# EU: during the course of any due diligence process.
# Similarity: 100.0%
#
# US: Other Users
# EU: Other Users
# Similarity: 100.0%
#
# US: When you create an Account, certain information will form part of your public profile and we will
# EU: When you create an Account, certain information will form part of your public profile and we will
# Similarity: 100.0%
#
# US: make it accessible to all accounts on PlayStation Network, on the Internet via playstation.com, and
# EU: make it accessible to all accounts on PlayStation Network, on the Internet via playstation.com, and
# Similarity: 100.0%
#
# US: some third-party websites, apps or services. This information includes:
# EU: some third-party websites, apps or services. This information includes:
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Your PlayStation Network Online ID
# EU: Your PlayStation Network Online ID.
# Similarity: 98.55%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: "About Me" statement, avatar, language, country and gaming scores and statistics
# EU: "About Me" statement, avatar, language, country and gaming scores and statistics.
# Similarity: 99.38%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Content you have shared
# EU: Content you have shared.
# Similarity: 97.87%
#
# US: features. This content will be accessible to other users who can then share that information further.
# EU: content will be accessible to other users who can then share that information further. We
# Similarity: 90.53%
#
# US: We recommend you consider carefully what you share and with whom you share your information.
# EU: recommend you consider carefully what you share and with whom you share your information.
# Similarity: 98.34%
#
# US: We may also index and use content which you have shared publicly, as part of our platform’s
# EU: We may also index and use content which you have shared publicly, as part of our platform’s
# Similarity: 100.0%
#
# US: features like Game Help, PlayStation profiles, or future PlayStation Network services.
# EU: features like Game Help, PlayStation profiles, or future PlayStation Network services.
# Similarity: 100.0%
#
# US: Government Authorities
# EU: Government & Authorities
# Similarity: 95.65%
#
# US: We may share your information with police and other government authorities if we believe that it
# EU: We may share your information with police, government, and other authorities if we believe that
# Similarity: 86.91%
#
# US: is reasonably necessary to comply with a law, regulation, or legal process, to detect, protect and
# EU: it is reasonably necessary to comply with a law, regulation, or legal process, to detect, protect and
# Similarity: 98.49%
#
# US: enforce the safety of any person, their property or their rights, to address fraud and security and
# EU: enforce the safety of any person, their property or their rights, to address fraud and security and
# Similarity: 100.0%
#
# US: report criminal activity. The majority of the cases in which we have shared information with police
# EU: report criminal activity. The majority of the cases in which we have shared information with police,
# Similarity: 99.5%
#
# US: and government authorities concern their investigations into stolen devices, unauthorized use of
# EU: government, and other authorities concern their investigations into stolen devices, unauthorised
# Similarity: 87.5%
#
# US: payment methods, or moderation purposes and safety of PlayStation Network and its users. In a
# EU: use of payment methods, or moderation purposes and safety of PlayStation Network and its users.
# Similarity: 93.62%
#
# US: small number of cases, we have also provided information in response to anti-fraud or more serious
# EU: In a small number of cases, we have also provided information in response to anti-fraud or more
# Similarity: 93.26%
#
# US: criminal investigations.
# EU: serious criminal investigations.
# Similarity: 85.71%
#
# US: Information Handling and Your Choices
# EU: Information Handling and Your Choices
# Similarity: 100.0%
#
# US: Children’s Information
# EU: Children’s Information
# Similarity: 100.0%
#
# US: in accordance with the practices described in this document, with the following exceptions.
# EU: practices described in this document, with the following exceptions.
# Similarity: 85.53%
#
# US: Information You Provide to Us
# EU: Information You Provide to Us
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: A parent only needs to provide limited information about their child (an email address and
# EU: A Responsible Adult only needs to provide limited information about their child (an email
# Similarity: 83.8%
#
# US: date-of-birth) to create an Account for their child. Providing gender is optional.
# EU: address and date-of-birth) to create an Account for their child. Providing gender is
# Similarity: 86.75%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Only with the parent's approval to create an Account for the child, can a child add their
# EU: Only with the Responsible Adult’s approval to create an Account for the child, can a child
# Similarity: 83.8%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: The spending limit of the Account for your child is set by the associated parent's Account.
# EU: The spending limit of the Account for your child is set by the associated Responsible
# Similarity: 86.36%
#
# US: Information You May Choose to Share
# EU: Information You May Choose to Share
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: A parent can control, through the “Free Communication” setting on their child's Account,
# EU: A Responsible Adult can control, through the “Free Communication” setting on their
# Similarity: 80.0%
#
# US: system software features. Please note that a child's Account can still (1) Send and receive
# EU: games, apps or via system software features. Please note that a child's Account can still (1)
# Similarity: 80.43%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: A parent can control their child's ability to post or view user-generated content, including
# EU: A Responsible Adult can control their child's ability to post or view user-generated content,
# Similarity: 85.41%
#
# US: photos, videos, drawings, and content imported from outside sources (any of which might
# EU: including photos, videos, drawings, and content imported from outside sources (any of
# Similarity: 87.21%
#
# US: contain PI) through the user-generated content control. This will not prevent video capture
# EU: which might contain PI) through the user-generated content control. This will not prevent
# Similarity: 85.56%
#
# US: of a child Account user's online gameplay.
# EU: video capture of a child Account user's online gameplay.
# Similarity: 85.71%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: disclosure to third parties, except when the disclosure is inherent to the Services we are
# EU: consenting to our disclosure to third parties, except when the disclosure is inherent to the
# Similarity: 81.32%
#
# US: When a parent allows their child's Account to participate in games, chat or user-generated content
# EU: When a Responsible Adult allows their child's Account to participate in games, chat or user-
# Similarity: 82.11%
#
# US: applications, or services that incorporate those features and the collection of information entered
# EU: of the games, applications, or services that incorporate those features and the collection of
# Similarity: 82.29%
#
# US: into such features by the child's Account (e.g. typing text into the chat feature).
# EU: information entered into such features by the child's Account (e.g. typing text into the chat feature).
# Similarity: 89.25%
#
# US: International Transfers
# EU: International Transfers
# Similarity: 100.0%
#
# US: Our Services are operated in the United States, United Kingdom, Japan, and other
# EU: Our Services are operated in the United States, United Kingdom, Japan, and other
# Similarity: 100.0%
#
# US: countries/areas/regions around the world. Please be aware that information we collect, including
# EU: countries/areas/regions around the world. Please be aware that information we collect, including
# Similarity: 100.0%
#
# US: PI, will be transferred to, processed and stored in these countries/areas/regions and, as such, courts,
# EU: PI, will be transferred to, processed and stored in these countries/areas/regions and, as such, courts,
# Similarity: 100.0%
#
# US: law enforcement, and other authorities in these countries may, in certain circumstances, be entitled
# EU: law enforcement, and other authorities in these countries may, in certain circumstances, be entitled
# Similarity: 100.0%
#
# US: to access your PI. We ensure there are adequate safeguards in place when transferring your
# EU: to access your PI. We ensure there are adequate safeguards in place when transferring your
# Similarity: 100.0%
#
# US: information outside your country by entering contracts with the recipients, European Commission
# EU: information outside your country by entering contracts with the recipients, European Commission
# Similarity: 100.0%
#
# US: Standard Contractual Clauses or otherwise that the transfer only occurs where permitted by
# EU: Standard Contractual Clauses or otherwise that the transfer only occurs where permitted by
# Similarity: 100.0%
#
# US: applicable law. By using our Services or providing us with any information through them, you
# EU: applicable law. By using our Services or providing us with any information through them, you
# Similarity: 100.0%
#
# US: acknowledge this transfer, processing, and storage of your information in these countries in which
# EU: acknowledge this transfer, processing, and storage of your information in these countries in which
# Similarity: 100.0%
#
# US: the privacy laws may not be as comprehensive as those in the country where you reside or are a
# EU: the privacy laws may not be as comprehensive as those in the country where you reside or are a
# Similarity: 100.0%
#
# US: citizen.
# EU: citizen.
# Similarity: 100.0%
#
# US: Security and Retention
# EU: Security and Retention
# Similarity: 100.0%
#
# US: We seek to maintain appropriate technical and organizational security measures that conform to
# EU: We seek to maintain appropriate technical and organisational security measures that conform to
# Similarity: 98.94%
#
# US: industry standards to help protect your information against unauthorized or accidental disclosure,
# EU: industry standards to help protect your information against unauthorised or accidental disclosure,
# Similarity: 98.98%
#
# US: access, misuse, loss, or alteration. Although we strive to protect your information, we cannot
# EU: access, misuse, loss, or alteration. Although we strive to protect your information, we cannot
# Similarity: 100.0%
#
# US: ensure or warrant the security of such information. There is no such thing as perfect security.
# EU: ensure or warrant the security of such information. There is no such thing as perfect security.
# Similarity: 100.0%
#
# US: We advise you to make use of the enhanced account access controls that we make available such
# EU: We advise you to make use of the enhanced account access controls that we make available such
# Similarity: 100.0%
#
# US: as 2-Step Verification. Please visit www.playstation.com and/or contact PlayStation Help and
# EU: as 2-Step Verification. Please visit www.playstation.com and/or contact PlayStation Help and
# Similarity: 100.0%
#
# US: Support if you need any assistance in restricting access to your devices or accounts.
# EU: Support if you need any assistance in restricting access to your devices or accounts.
# Similarity: 100.0%
#
# US: Please keep any passwords and passcodes for your devices and accounts safe and do not disclose
# EU: Please keep any passwords and passcodes for your devices and accounts safe and do not disclose
# Similarity: 100.0%
#
# US: them to anyone else. Consider ensuring automatic account log-in setting is disabled and the setting
# EU: them to anyone else. Consider ensuring automatic account log-in setting is disabled and the setting
# Similarity: 100.0%
#
# US: requiring a password to be entered before completing purchases is enabled, particularly if your
# EU: requiring a password to be entered before completing purchases is enabled, particularly if your
# Similarity: 100.0%
#
# US: PlayStation device is shared with others. You should contact PlayStation Support immediately if
# EU: PlayStation device is shared with others. You should contact PlayStation Support immediately if
# Similarity: 100.0%
#
# US: you become aware of any unauthorized use of your accounts or other security breaches.
# EU: you become aware of any unauthorised use of your accounts or other security breaches.
# Similarity: 98.82%
#
# US: We may retain information about you as long as it is necessary for us to fulfill the purposes outlined
# EU: We may retain information about you as long as it is necessary for us to fulfil the purposes outlined
# Similarity: 99.51%
#
# US: in this policy. In addition, we may retain your information for an additional period as is permitted
# EU: in this Privacy Policy. In addition, we may retain your information for an additional period as is
# Similarity: 89.9%
#
# US: or required to, among other things, comply with our legal obligations, resolve disputes, and enforce
# EU: permitted or required to, among other things, comply with our legal obligations, resolve disputes,
# Similarity: 88.89%
#
# US: agreements. Where required by applicable law, we shall delete your information when the
# EU: and enforce agreements. Where required by applicable law, we shall delete your information when
# Similarity: 91.21%
#
# US: information is no longer necessary or requested to do so. Even if we delete your information from
# EU: the information is no longer necessary or requested to do so. Even if we delete your information
# Similarity: 95.34%
#
# US: active databases, the information may remain on backup or archival media as well as other
# EU: from active databases, the information may remain on backup or archival media as well as other
# Similarity: 97.27%
#
# US: information systems.
# EU: information systems.
# Similarity: 100.0%
#
# US: Your Choices and Rights
# EU: Your Choices and Rights
# Similarity: 100.0%
#
# US: Your Choices
# EU: Your Choices
# Similarity: 100.0%
#
# US: You may have certain choices about how your information is collected, used, stored, and
# EU: You may have certain choices about how your information is collected, used, stored, and
# Similarity: 100.0%
#
# US: shared.  These options can be accessed through your Account or device settings.  Please ensure
# EU: shared.  These options can be accessed through your Account or device settings.  Please ensure
# Similarity: 100.0%
#
# US: that your information is up-to-date. Among others, you have the following choices:
# EU: that your information is up to date. Among others, you have the following choices:
# Similarity: 97.56%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Personalized content and marketing: Whether we may use the information we have
# EU: Personalised content and marketing: Whether we may use the information we have
# Similarity: 98.72%
#
# US: collected about you to personalize advertising and purchase recommendations. Note that
# EU: collected about you to personalise advertising and purchase recommendations. Note that
# Similarity: 98.84%
#
# US: we will always slightly customize what you see (e.g. to avoid displaying content you've
# EU: we will always slightly customise what you see (e.g. to avoid displaying content you've
# Similarity: 98.85%
#
# US: already purchased from the PlayStation Store), and some older devices (e.g. PS3/Vita),
# EU: already purchased from the PlayStation Store), and some older devices, apps and games
# Similarity: 83.04%
#
# US: apps and games may still show some commercial personalization.
# EU: may still show some commercial personalisation.
# Similarity: 84.4%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Personalized communications: Whether we may use the information we have collected, to
# EU: Personalised communications: Whether we may use the information we have collected, to
# Similarity: 98.82%
#
# US: personalize emails and notifications.
# EU: personalise emails and notifications.
# Similarity: 97.3%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Limited Data/Service Data and Full Data/Advanced Data collection: Whether we may
# EU: Limited Data/Service Data and Full Data/Additional Data collection: Whether we may
# Similarity: 92.59%
#
# US: collect only the Limited Data necessary to provide our Services, or Full Data to enable a
# EU: collect only the Limited Data necessary to provide our Services, or Full Data to enable a
# Similarity: 100.0%
#
# US: richer experience.
# EU: richer experience.
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: E-Mail Messages: Whether we send you marketing emails.
# EU: E-Mail Messages: Whether we send you marketing emails.
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Sharing social PI: Whether to share other information, such as your real, name, PlayStation
# EU: Sharing social PI: Whether to share other information, such as your real, name, PlayStation
# Similarity: 100.0%
#
# US: Network friends, or activities.
# EU: Network friends, or activities.
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Shared content: Whether to share content such as gameplay videos with other users.
# EU: Shared content: Whether to share content such as gameplay videos with other users.
# Similarity: 100.0%
#
# US: in this Privacy Policy.
# EU: with this Privacy Policy.
# Similarity: 91.67%
#
# US: Your Rights
# EU: Your Rights
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: •
# EU: •
# Similarity: 100.0%
#
# US: Right of Deletion: You have the right to request that we delete the PI we have collected or
# EU: Right of Erasure: You have the right to request that we delete the PI we have collected or
# Similarity: 92.82%
#
# US: retained about you in some circumstances as defined by law. To request removal of certain
# EU: retained about you in some circumstances as defined by law.  To request removal of certain
# Similarity: 99.44%
#
# US: In some cases, your choices to provide, change or delete information may affect our ability to
# EU: In some cases, your choices to provide, change or delete information may affect our ability to
# Similarity: 100.0%
#
# US: deliver our Services, or your user experience. We may decline to process requests which are not
# EU: deliver our Services, or your user experience. We may decline to process requests which are not
# Similarity: 100.0%
#
# US: otherwise required by applicable law. You have the right not to be unlawfully discriminated against
# EU: otherwise required by applicable law. You have the right not to be unlawfully discriminated against
# Similarity: 100.0%
#
# US: because you have exercised these rights.
# EU: because you have exercised these rights.
# Similarity: 100.0%
#
# US: to
# EU: to:
# Similarity: 80.0%
#
# US: or
# EU: For
# Similarity: 80.0%
#
# US: or
# EU: For
# Similarity: 80.0%
#
# US: Complaints
# EU: Complaints
# Similarity: 100.0%
#
# US: Changes to this Policy
# EU: Changes to this Policy
# Similarity: 100.0%
#
# US: We may revise this Privacy Policy at any time and we will update this Policy with any revisions.
# EU: We may revise this Privacy Policy at any time and we will update this Privacy Policy with any
# Similarity: 89.95%
#
# US: By continuing to access or use the Services after those changes become effective, you acknowledge
# EU: revisions. By continuing to access or use the Services after those changes become effective, you
# Similarity: 88.08%
#
# US: and accept that PI will be handled in accordance with the revised Privacy Policy.
# EU: acknowledge and accept that PI will be handled in accordance with the revised Privacy Policy.
# Similarity: 93.1%
